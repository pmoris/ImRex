# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview-of-the-contents-of-the-VDJdb-datasets" data-toc-modified-id="Overview-of-the-contents-of-the-VDJdb-datasets-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview of the contents of the VDJdb datasets</a></span><ul class="toc-item"><li><span><a href="#Brief-statistics-generated-through-bash-script" data-toc-modified-id="Brief-statistics-generated-through-bash-script-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Brief statistics generated through bash script</a></span><ul class="toc-item"><li><span><a href="#Statistics-for-GitHub-release-vdjdb.txt" data-toc-modified-id="Statistics-for-GitHub-release-vdjdb.txt-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Statistics for GitHub release vdjdb.txt</a></span><ul class="toc-item"><li><span><a href="#vdjdb.txt" data-toc-modified-id="vdjdb.txt-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>vdjdb.txt</a></span></li><li><span><a href="#vdjdb.slim" data-toc-modified-id="vdjdb.slim-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>vdjdb.slim</a></span></li></ul></li><li><span><a href="#Statistics-for-VDJdb-data-browser" data-toc-modified-id="Statistics-for-VDJdb-data-browser-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Statistics for VDJdb data browser</a></span></li></ul></li></ul></li><li><span><a href="#Comparison-of-slim-and-normal-file-in-the-VDJdb-GitHub-releases-(January-2020)" data-toc-modified-id="Comparison-of-slim-and-normal-file-in-the-VDJdb-GitHub-releases-(January-2020)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Comparison of slim and normal file in the VDJdb GitHub releases (January 2020)</a></span><ul class="toc-item"><li><span><a href="#Duplicate-CDR3-epitope-pairs" data-toc-modified-id="Duplicate-CDR3-epitope-pairs-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Duplicate CDR3-epitope pairs</a></span></li><li><span><a href="#Spurious-sequences" data-toc-modified-id="Spurious-sequences-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Spurious sequences</a></span></li></ul></li><li><span><a href="#Comparison-of-VDJdb-web-export-and-GitHub-Release-Aug" data-toc-modified-id="Comparison-of-VDJdb-web-export-and-GitHub-Release-Aug-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Comparison of VDJdb web export and GitHub Release Aug</a></span><ul class="toc-item"><li><span><a href="#Comparison-of-spurious-sequences-and-VDJdb-web-dataset" data-toc-modified-id="Comparison-of-spurious-sequences-and-VDJdb-web-dataset-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Comparison of spurious sequences and VDJdb web dataset</a></span><ul class="toc-item"><li><span><a href="#The-web-version-is-equal-to-the-GitHub-release-(normal)-after-filtering-on-cdr3fix.good" data-toc-modified-id="The-web-version-is-equal-to-the-GitHub-release-(normal)-after-filtering-on-cdr3fix.good-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>The web version is equal to the GitHub release (normal) after filtering on cdr3fix.good</a></span></li></ul></li><li><span><a href="#Web-versus-slim" data-toc-modified-id="Web-versus-slim-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Web versus slim</a></span></li><li><span><a href="#The-slim-GitHub-release-still-contains-duplicated-and-spurious-sequences" data-toc-modified-id="The-slim-GitHub-release-still-contains-duplicated-and-spurious-sequences-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>The slim GitHub release still contains duplicated and spurious sequences</a></span></li></ul></li><li><span><a href="#In-depth-statistics-and-figures-for-the-VDJdb-GitHub-January-2020-release-(after-filtering)" data-toc-modified-id="In-depth-statistics-and-figures-for-the-VDJdb-GitHub-January-2020-release-(after-filtering)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>In-depth statistics and figures for the VDJdb GitHub January 2020 release (after filtering)</a></span><ul class="toc-item"><li><span><a href="#Statistics-for-all-data-(all-species)" data-toc-modified-id="Statistics-for-all-data-(all-species)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Statistics for all data (all species)</a></span></li><li><span><a href="#Human-CDR3-epitope-pairs" data-toc-modified-id="Human-CDR3-epitope-pairs-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Human CDR3-epitope pairs</a></span></li><li><span><a href="#Human-TRB-CDR3-epitope-pairs" data-toc-modified-id="Human-TRB-CDR3-epitope-pairs-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Human TRB CDR3-epitope pairs</a></span></li><li><span><a href="#10x-data-exploration" data-toc-modified-id="10x-data-exploration-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>10x data exploration</a></span></li><li><span><a href="#Removing-over-abundant-10x-data-entries" data-toc-modified-id="Removing-over-abundant-10x-data-entries-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Removing over-abundant 10x data entries</a></span></li><li><span><a href="#How-much-data-is-lost-due-to-filtering-on-spurious-entries?" data-toc-modified-id="How-much-data-is-lost-due-to-filtering-on-spurious-entries?-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>How much data is lost due to filtering on spurious entries?</a></span></li></ul></li><li><span><a href="#Create-figures-for-filtered-data-(including-length-restrictions)" data-toc-modified-id="Create-figures-for-filtered-data-(including-length-restrictions)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Create figures for filtered data (including length restrictions)</a></span><ul class="toc-item"><li><span><a href="#Comparison-to-Dean-et-al.-negative-reference-TCR-set" data-toc-modified-id="Comparison-to-Dean-et-al.-negative-reference-TCR-set-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Comparison to Dean et al. negative reference TCR set</a></span></li><li><span><a href="#TRB-only" data-toc-modified-id="TRB-only-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>TRB only</a></span><ul class="toc-item"><li><span><a href="#Epitope-and-CDR3-length-distribution" data-toc-modified-id="Epitope-and-CDR3-length-distribution-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Epitope and CDR3 length distribution</a></span><ul class="toc-item"><li><span><a href="#No-grouping" data-toc-modified-id="No-grouping-5.2.1.1"><span class="toc-item-num">5.2.1.1&nbsp;&nbsp;</span>No grouping</a></span></li><li><span><a href="#Per-MHC:" data-toc-modified-id="Per-MHC:-5.2.1.2"><span class="toc-item-num">5.2.1.2&nbsp;&nbsp;</span>Per MHC:</a></span></li></ul></li></ul></li><li><span><a href="#Can-MHCI-and-MHCII-share-epitopes?" data-toc-modified-id="Can-MHCI-and-MHCII-share-epitopes?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Can MHCI and MHCII share epitopes?</a></span></li><li><span><a href="#TRB-and-TRA" data-toc-modified-id="TRB-and-TRA-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>TRB and TRA</a></span><ul class="toc-item"><li><span><a href="#Epitope-counts" data-toc-modified-id="Epitope-counts-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Epitope counts</a></span><ul class="toc-item"><li><span><a href="#Combined-figure---histogram-of-abundances-and-epitope-counts" data-toc-modified-id="Combined-figure---histogram-of-abundances-and-epitope-counts-5.4.1.1"><span class="toc-item-num">5.4.1.1&nbsp;&nbsp;</span>Combined figure - histogram of abundances and epitope counts</a></span></li></ul></li></ul></li><li><span><a href="#MHC-distribution" data-toc-modified-id="MHC-distribution-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>MHC distribution</a></span></li><li><span><a href="#Combined-figure" data-toc-modified-id="Combined-figure-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Combined figure</a></span><ul class="toc-item"><li><span><a href="#Simple-figure" data-toc-modified-id="Simple-figure-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Simple figure</a></span></li><li><span><a href="#Length-only" data-toc-modified-id="Length-only-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>Length only</a></span></li><li><span><a href="#Chain-split-and-per-figure-MHC" data-toc-modified-id="Chain-split-and-per-figure-MHC-5.6.3"><span class="toc-item-num">5.6.3&nbsp;&nbsp;</span>Chain split and per-figure MHC</a></span></li><li><span><a href="#MHC-split-and-per-figure-chains-+-more-details" data-toc-modified-id="MHC-split-and-per-figure-chains-+-more-details-5.6.4"><span class="toc-item-num">5.6.4&nbsp;&nbsp;</span>MHC split and per-figure chains + more details</a></span></li></ul></li><li><span><a href="#Dean-reference-set-TCR-distribution" data-toc-modified-id="Dean-reference-set-TCR-distribution-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Dean reference set TCR distribution</a></span></li></ul></li><li><span><a href="#TODO" data-toc-modified-id="TODO-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>TODO</a></span></li><li><span><a href="#Difference-between-August-2019-and-January-2020-release" data-toc-modified-id="Difference-between-August-2019-and-January-2020-release-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Difference between August 2019 and January 2020 release</a></span><ul class="toc-item"><li><span><a href="#New-values-analysis" data-toc-modified-id="New-values-analysis-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>New values analysis</a></span></li><li><span><a href="#New-unique-pairs" data-toc-modified-id="New-unique-pairs-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>New unique pairs</a></span></li></ul></li></ul></div>

# %%
import json

import pandas as pd
from pandas.io.json import json_normalize
from pathlib import Path

from src.config import PROJECT_ROOT
from src.preprocessing import preprocess_vdjdb

# %% [markdown]
# # Overview of the contents of the VDJdb datasets
#
# As described in `data/raw/README.md`:
#
# `data/raw/vdjdb`: contains a data dump of VDJdb TCR-epitope pairs ([https://vdjdb.cdr3.net](https://vdjdb.cdr3.net)), see [./vdjdb/README.md](./data/raw/VDJdb/README.md) for additional information about the origin and statistics of the files.
#
# The files in this directory were retrieved from https://vdjdb.cdr3.net and https://github.com/antigenomics/vdjdb-db/releases on 21 November 2019. At this time, the last update to VDJdb had happened on 07 August 2019 (GitHub release August 8).
#
# - `vdjdb-2020-01-20.zip` is the January 2018 GitHub release and contains three different types of files:
#     - `vdjdb.txt`: the full set of CDR3-epitope pairs in VDJdb, refered to as the normal or standard file in this document.
#     - `vdjdb.slim.txt`: a reduced version of the former file.
#     - `vdjdb_full.txt`: contains some additional information compared to the standard file; among other things it uses a separate column for `cdr3.alpha` and `cdr3.beta` sequences.
# - `vdjdb-browser.txt`: contains TRA and TRB chains and their epitope targets retrieved from the VDJdb web browser (August 2019 release) with the following options:
#     - All species
#     - Both TRA and TRB chains
#     - Both MHC types
#     - No sequence length restriction
#     - All assay types
#     - No minimum confidence score
#     - **No spurious CDR3 (non-canonical or unmapped V/J)**

# %% [markdown]
# ## Brief statistics generated through bash script
#
# These statistics can be obtained by running `bash data/raw/vdjdb/vdjdb-content-analyser.sh output-summary.md input-file.tsv`.
#
#
# ### Statistics for GitHub release vdjdb.txt
#
# #### vdjdb.txt
#
#
# | Metric                                                         | Count                                                                                                                                       | Command                                                                                                                                        |
# |----------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------|
# | Total number of records                                        | 76164                                                                                                         | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt  |  wc -l`                                                                                                         |
# | TRA records                                                    | 31244                                                                                     | `awk '$2 == "TRA" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | wc -l`                                                                                     |
# | TRB records                                                    | 44920                                                                                     | `awk '$2 == "TRB" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | wc -l`                                                                                     |
# | Unique TRA sequences                                           | 22352                                                                           | `awk '$2 == "TRA" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                           |
# | Unique TRB sequences                                           | 33977                                                                           | `awk '$2 == "TRB" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                           |
# | Unique CDR3 sequences                                          | 56327                                                                                     | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -f3 | sort -u | wc -l`                                                                                       |
# | Unique epitope sequences                                       | 222                                                                                    | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -f10 | sort -u | wc -l`                                                                                      |
# | Unique epitope sequences for TRA records                       | 188                                                                          | `awk '$2 == "TRA" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                          |
# | Unique epitope sequences for TRB records                       | 227                                                                          | `awk '$2 == "TRB" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                          |
# | Unique CDR3-epitope sequence pairs                             | 61555                                                                         | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -d $'\t' -f3,10 | sort -u | wc -l`                                                                           |
# | Unique TRA-CDR3-epitope sequence pairs                         | 25166                                                                       | `awk '$2 == "TRA" { print ,data/raw/vdjdb/vdjdb-2020-01-20-summary.md0 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                        |
# | Unique TRB-CDR3-epitope sequence pairs                         | 36386                                                                       | `awk '$2 == "TRB" { print ,data/raw/vdjdb/vdjdb-2020-01-20-summary.md0 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                        |
# | Number of epitope sequences shared between TRA and TRB records | 154   | `comm -12 <(awk '$2 == "TRA" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) <(awk '$2 == "TRB" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) | wc -l` |
# | Number of CDR3 sequences shared between TRA and TRB records    | 2     | `comm -12 <(awk '$2 == "TRA" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) <(awk '$2 == "TRB" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) | wc -l`   |
# | Epitope distribution for the unique CDR3-epitope pairs         |                                 | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -d $'\t' -f3,10 | sort -u | cut -f2 | sort | uniq -c | sort -nr | head -20`                                  |
#
#   24639 KLGGALQAK
#    6744 NLVPMVATV
#    6600 GILGFVFTL
#    3255 AVFDRKSDAK
#    1654 ELAGIGILTV
#    1501 RAKFKQLL
#    1190 GLCTLVAML
#    1088 IVTDFSVIK
#     819 RLRAEAQVK
#     685 LLWNGPMAV
#     617 LLLGIGILV
#     597 TTPESANL
#     597 SSLENFRAYV
#     586 SSYRRPVGI
#     564 FRDYVDRFYKTLRAEQASQE
#     548 PKYVKQNTLKLAT
#     530 CTPYDINQM
#     417 HGIRNASFI
#     383 ASNENMETM
#     334 KRWIILGLNK
#
# **Human-only records**
#
# | Metric                                                             | Count                                                                                                                                                                          | Command                                                                                                                                                                                                 |
# |--------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |   Total number of records                                          | 68067                                                                                                                  | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt |  wc -l`                                                                                                                                         |
# |   TRA records                                                      | 28183                                                                                                 | `awk '$2 == "TRA" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | wc -l`                                                                                                                     |
# |   TRB records                                                      | 39884                                                                                                | `awk '$2 == "TRB" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | wc -l`                                                                                                                     |
# |   Unique TRA sequences                                             | 20373                                                                                      | `awk '$2 == "TRA" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                                                           |
# |   Unique TRB sequences                                             | 30852                                                                                      | `awk '$2 == "TRB" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                                                           |
# |   Unique CDR3 sequences                                            | 51223                                                                                               | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -f3 | sort -u | wc -l`                                                                                                                      |
# |   Unique epitope sequences                                         | 186                                                                                              | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -f10 | sort -u | wc -l`                                                                                                                     |
# |   Unique epitope sequences for TRA records                         | 126                                                                                      | `awk '$2 == "TRA" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                                                           |
# |   Unique epitope sequences for TRB records                         | 184                                                                                      | `awk '$2 == "TRB" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                                                           |
# |   Unique CDR3-epitope sequence pairs                               | 56181                                                                                   | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -d $'\t' -f3,10 | sort -u | wc -l`                                                                                                          |
# |   Unique TRA-CDR3-epitope sequence pairs                           | 23059                                                                                   | `awk '$2 == "TRA" && $6 == "HomoSapiens" { print $3,$10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                                                       |
# |   Unique TRB-CDR3-epitope sequence pairs                           | 33124                                                                                   | `awk '$2 == "TRB" && $6 == "HomoSapiens" { print $3,$10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u | wc -l`                                                                                                       |
# |   Number of epitope sequences shared between TRA and TRB records   | 124|`comm -12 <(awk '$2 == "TRA" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) <(awk '$2 == "TRB" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) | wc -l`   |
# |   Number of CDR3 sequences shared between TRA and TRB records      | 2|`comm -12 <(awk '$2 == "TRA" && $6 == "HomoSapiens" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) <(awk '$2 == "TRB" && $6 == "HomoSapiens" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | sort -u) | wc -l`     |
# |   Epitope distribution for the unique CDR3-epitope pairs           |                             | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt | cut -d $'\t' -f3,10 | sort -u | cut -f2 | sort | uniq -c | sort -nr | head -20`                                                                 |
#
#   24367 KLGGALQAK
#    6680 NLVPMVATV
#    6531 GILGFVFTL
#    3222 AVFDRKSDAK
#    1642 ELAGIGILTV
#    1492 RAKFKQLL
#    1165 GLCTLVAML
#    1083 IVTDFSVIK
#     810 RLRAEAQVK
#     676 LLWNGPMAV
#     588 LLLGIGILV
#     562 FRDYVDRFYKTLRAEQASQE
#     534 PKYVKQNTLKLAT
#     334 KRWIILGLNK
#     240 GLIYNRMGAVTTEV
#     227 QARQMVQAMRTIGTHP
#     209 KAFSPEVIPMF
#     207 TPRVTGGGAM
#     203 VTEHDTLLY
#     203 CINGVCWTV
#
# #### vdjdb.slim
#
#
# | Metric                                                         | Count                                                                                                                                       | Command                                                                                                                                        |
# |----------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------|
# | Total number of records                                        | 61557                                                                                                         | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt  |  wc -l`                                                                                                         |
# | TRA records                                                    | 0                                                                                     | `awk '$2 == "TRA" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | wc -l`                                                                                     |
# | TRB records                                                    | 0                                                                                     | `awk '$2 == "TRB" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | wc -l`                                                                                     |
# | Unique TRA sequences                                           | 0                                                                           | `awk '$2 == "TRA" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                           |
# | Unique TRB sequences                                           | 0                                                                           | `awk '$2 == "TRB" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                           |
# | Unique CDR3 sequences                                          | 3                                                                                     | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -f3 | sort -u | wc -l`                                                                                       |
# | Unique epitope sequences                                       | 7                                                                                    | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -f10 | sort -u | wc -l`                                                                                      |
# | Unique epitope sequences for TRA records                       | 0                                                                          | `awk '$2 == "TRA" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                          |
# | Unique epitope sequences for TRB records                       | 0                                                                          | `awk '$2 == "TRB" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                          |
# | Unique CDR3-epitope sequence pairs                             | 18                                                                         | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -d $'\t' -f3,10 | sort -u | wc -l`                                                                           |
# | Unique TRA-CDR3-epitope sequence pairs                         | 0                                                                       | `awk '$2 == "TRA" { print ,data/raw/vdjdb/vdjdb-2020-01-20-slim-summary.md0 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                        |
# | Unique TRB-CDR3-epitope sequence pairs                         | 0                                                                       | `awk '$2 == "TRB" { print ,data/raw/vdjdb/vdjdb-2020-01-20-slim-summary.md0 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                        |
# | Number of epitope sequences shared between TRA and TRB records | 0   | `comm -12 <(awk '$2 == "TRA" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) <(awk '$2 == "TRB" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) | wc -l` |
# | Number of CDR3 sequences shared between TRA and TRB records    | 0     | `comm -12 <(awk '$2 == "TRA" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) <(awk '$2 == "TRB" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) | wc -l`   |
# | Epitope distribution for the unique CDR3-epitope pairs         |                                 | `tail -n +2 data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -d $'\t' -f3,10 | sort -u | cut -f2 | sort | uniq -c | sort -nr | head -20`                                  |
#
#       3 5
#       3 4
#       3 3
#       3 2
#       3 -1
#       2 6
#       1 1
#
# **Human-only records**
#
# | Metric                                                             | Count                                                                                                                                                                          | Command                                                                                                                                                                                                 |
# |--------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |   Total number of records                                          | 2932                                                                                                                  | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt |  wc -l`                                                                                                                                         |
# |   TRA records                                                      | 0                                                                                                 | `awk '$2 == "TRA" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | wc -l`                                                                                                                     |
# |   TRB records                                                      | 0                                                                                                | `awk '$2 == "TRB" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | wc -l`                                                                                                                     |
# |   Unique TRA sequences                                             | 0                                                                                      | `awk '$2 == "TRA" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                                                           |
# |   Unique TRB sequences                                             | 0                                                                                      | `awk '$2 == "TRB" && $6 == "HomoSapiens"  { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                                                           |
# |   Unique CDR3 sequences                                            | 2                                                                                               | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -f3 | sort -u | wc -l`                                                                                                                      |
# |   Unique epitope sequences                                         | 7                                                                                              | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -f10 | sort -u | wc -l`                                                                                                                     |
# |   Unique epitope sequences for TRA records                         | 0                                                                                      | `awk '$2 == "TRA" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                                                           |
# |   Unique epitope sequences for TRB records                         | 0                                                                                      | `awk '$2 == "TRB" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                                                           |
# |   Unique CDR3-epitope sequence pairs                               | 10                                                                                   | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -d $'\t' -f3,10 | sort -u | wc -l`                                                                                                          |
# |   Unique TRA-CDR3-epitope sequence pairs                           | 0                                                                                   | `awk '$2 == "TRA" && $6 == "HomoSapiens" { print $3,$10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                                                       |
# |   Unique TRB-CDR3-epitope sequence pairs                           | 0                                                                                   | `awk '$2 == "TRB" && $6 == "HomoSapiens" { print $3,$10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u | wc -l`                                                                                                       |
# |   Number of epitope sequences shared between TRA and TRB records   | 0|`comm -12 <(awk '$2 == "TRA" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) <(awk '$2 == "TRB" && $6 == "HomoSapiens" { print $10 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) | wc -l`   |
# |   Number of CDR3 sequences shared between TRA and TRB records      | 0|`comm -12 <(awk '$2 == "TRA" && $6 == "HomoSapiens" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) <(awk '$2 == "TRB" && $6 == "HomoSapiens" { print $3 }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | sort -u) | wc -l`     |
# |   Epitope distribution for the unique CDR3-epitope pairs           |                             | `awk '$6 == "HomoSapiens" { print }' data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt | cut -d $'\t' -f3,10 | sort -u | cut -f2 | sort | uniq -c | sort -nr | head -20`                                                                 |
#
#       2 5
#       2 4
#       2 3
#       1 6
#       1 2
#       1 1
#       1 -1
#
#
# ### Statistics for VDJdb data browser
#
#
# | Metric                                                         | Count                                                                                                                                       | Command                                                                                                                                        |
# |----------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------|
# | Total number of records                                        | 73224                                                                                                         | `tail -n +2 vdjdb-browser.tsv  |  wc -l`                                                                                                         |
# | TRA records                                                    | 29479                                                                                     | `awk '$2 == "TRA" { print $3 }' vdjdb-browser.tsv | wc -l`                                                                                     |
# | TRB records                                                    | 43745                                                                                     | `awk '$2 == "TRB" { print $3 }' vdjdb-browser.tsv | wc -l`                                                                                     |
# | Unique TRA sequences                                           | 20888                                                                           | `awk '$2 == "TRA" { print $3 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                           |
# | Unique TRB sequences                                           | 33112                                                                           | `awk '$2 == "TRB" { print $3 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                           |
# | Unique CDR3 sequences                                          | 54000                                                                                     | `tail -n +2 vdjdb-browser.tsv | cut -f3 | sort -u | wc -l`                                                                                       |
# | Unique epitope sequences                                       | 212                                                                                    | `tail -n +2 vdjdb-browser.tsv | cut -f10 | sort -u | wc -l`                                                                                      |
# | Unique epitope sequences for TRA records                       | 141                                                                          | `awk '$2 == "TRA" { print $10 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                          |
# | Unique epitope sequences for TRB records                       | 210                                                                          | `awk '$2 == "TRB" { print $10 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                          |
# | Unique CDR3-epitope sequence pairs                             | 59072                                                                         | `tail -n +2 vdjdb-browser.tsv | cut -d $'\t' -f3,10 | sort -u | wc -l`                                                                           |
# | Unique TRA-CDR3-epitope sequence pairs                         | 23578                                                                       | `awk '$2 == "TRA" { print ,vdjdb-browser-summary.md0 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                        |
# | Unique TRB-CDR3-epitope sequence pairs                         | 35494                                                                       | `awk '$2 == "TRB" { print ,vdjdb-browser-summary.md0 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                        |
# | Number of epitope sequences shared between TRA and TRB records | 139   | `comm -12 <(awk '$2 == "TRA" { print $10 }' vdjdb-browser.tsv | sort -u) <(awk '$2 == "TRB" { print $10 }' vdjdb-browser.tsv | sort -u) | wc -l` |
# | Number of CDR3 sequences shared between TRA and TRB records    | 0     | `comm -12 <(awk '$2 == "TRA" { print $3 }' vdjdb-browser.tsv | sort -u) <(awk '$2 == "TRB" { print $3 }' vdjdb-browser.tsv | sort -u) | wc -l`   |
# | Epitope distribution for the unique CDR3-epitope pairs         |                                 | `tail -n +2 vdjdb-browser.tsv | cut -d $'\t' -f3,10 | sort -u | cut -f2 | sort | uniq -c | sort -nr | head -20`                                  |
#
#       24041 KLGGALQAK
#        6514 NLVPMVATV
#        6389 GILGFVFTL
#        3175 AVFDRKSDAK
#        1624 ELAGIGILTV
#        1472 RAKFKQLL
#        1142 GLCTLVAML
#        1067 IVTDFSVIK
#         800 RLRAEAQVK
#         652 LLWNGPMAV
#         585 SSLENFRAYV
#         577 LLLGIGILV
#         562 SSYRRPVGI
#         523 PKYVKQNTLKLAT
#         511 TTPESANL
#         508 FRDYVDRFYKTLRAEQASQE
#         500 CTPYDINQM
#         398 HGIRNASFI
#         345 ASNENMETM
#         325 KRWIILGLNK
#
# **Human-only records**
#
# | Metric                                                             | Count                                                                                                                                                                          | Command                                                                                                                                                                                                 |
# |--------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |   Total number of records                                          | 66597                                                                                                                  | `awk '$6 == "HomoSapiens" { print }' vdjdb-browser.tsv |  wc -l`                                                                                                                                         |
# |   TRA records                                                      | 27295                                                                                                 | `awk '$2 == "TRA" && $6 == "HomoSapiens"  { print $3 }' vdjdb-browser.tsv | wc -l`                                                                                                                     |
# |   TRB records                                                      | 39302                                                                                                | `awk '$2 == "TRB" && $6 == "HomoSapiens"  { print $3 }' vdjdb-browser.tsv | wc -l`                                                                                                                     |
# |   Unique TRA sequences                                             | 19637                                                                                      | `awk '$2 == "TRA" && $6 == "HomoSapiens"  { print $3 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                                                           |
# |   Unique TRB sequences                                             | 30377                                                                                      | `awk '$2 == "TRB" && $6 == "HomoSapiens"  { print $3 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                                                           |
# |   Unique CDR3 sequences                                            | 50014                                                                                               | `awk '$6 == "HomoSapiens" { print }' vdjdb-browser.tsv | cut -f3 | sort -u | wc -l`                                                                                                                      |
# |   Unique epitope sequences                                         | 177                                                                                              | `awk '$6 == "HomoSapiens" { print }' vdjdb-browser.tsv | cut -f10 | sort -u | wc -l`                                                                                                                     |
# |   Unique epitope sequences for TRA records                         | 117                                                                                      | `awk '$2 == "TRA" && $6 == "HomoSapiens" { print $10 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                                                           |
# |   Unique epitope sequences for TRB records                         | 175                                                                                      | `awk '$2 == "TRB" && $6 == "HomoSapiens" { print $10 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                                                           |
# |   Unique CDR3-epitope sequence pairs                               | 54887                                                                                   | `awk '$6 == "HomoSapiens" { print }' vdjdb-browser.tsv | cut -d $'\t' -f3,10 | sort -u | wc -l`                                                                                                          |
# |   Unique TRA-CDR3-epitope sequence pairs                           | 22248                                                                                   | `awk '$2 == "TRA" && $6 == "HomoSapiens" { print $3,$10 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                                                       |
# |   Unique TRB-CDR3-epitope sequence pairs                           | 32639                                                                                   | `awk '$2 == "TRB" && $6 == "HomoSapiens" { print $3,$10 }' vdjdb-browser.tsv | sort -u | wc -l`                                                                                                       |
# |   Number of epitope sequences shared between TRA and TRB records   | 115|`comm -12 <(awk '$2 == "TRA" && $6 == "HomoSapiens" { print $10 }' vdjdb-browser.tsv | sort -u) <(awk '$2 == "TRB" && $6 == "HomoSapiens" { print $10 }' vdjdb-browser.tsv | sort -u) | wc -l`   |
# |   Number of CDR3 sequences shared between TRA and TRB records      | 0|`comm -12 <(awk '$2 == "TRA" && $6 == "HomoSapiens" { print $3 }' vdjdb-browser.tsv | sort -u) <(awk '$2 == "TRB" && $6 == "HomoSapiens" { print $3 }' vdjdb-browser.tsv | sort -u) | wc -l`     |
# |   Epitope distribution for the unique CDR3-epitope pairs           |                             | `awk '$6 == "HomoSapiens" { print }' vdjdb-browser.tsv | cut -d $'\t' -f3,10 | sort -u | cut -f2 | sort | uniq -c | sort -nr | head -20`                                                                 |
#
#       24041 KLGGALQAK
#        6514 NLVPMVATV
#        6389 GILGFVFTL
#        3175 AVFDRKSDAK
#        1624 ELAGIGILTV
#        1472 RAKFKQLL
#        1142 GLCTLVAML
#        1067 IVTDFSVIK
#         800 RLRAEAQVK
#         652 LLWNGPMAV
#         577 LLLGIGILV
#         523 PKYVKQNTLKLAT
#         508 FRDYVDRFYKTLRAEQASQE
#         325 KRWIILGLNK
#         240 GLIYNRMGAVTTEV
#         226 QARQMVQAMRTIGTHP
#         201 VTEHDTLLY
#         201 CINGVCWTV
#         199 TPRVTGGGAM
#         193 KAFSPEVIPMF

# %% [markdown]
# # Comparison of slim and normal file in the VDJdb GitHub releases (January 2020)

# %%
vdjdb_slim_path = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.slim.txt"
df_slim = pd.read_csv(vdjdb_slim_path, sep="\t")

vdjdb_normal_path = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt"
df_normal = pd.read_csv(vdjdb_normal_path, sep="\t")
# expand the json/dict-like columns
df_normal = (
    df_normal.join(json_normalize(df_normal["method"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("method."))
    .join(json_normalize(df_normal["meta"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("meta."))
    .join(json_normalize(df_normal["cdr3fix"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("cdr3fix."))
    .drop(["method", "meta", "cdr3fix"], axis=1)
)
columns = ["cdr3", "antigen.epitope"]

# create column based on cdr3 and epitope sequences
df_normal["merged"] = df_normal["cdr3"] + "-" + df_normal["antigen.epitope"]
df_slim["merged"] = df_slim["cdr3"] + "-" + df_slim["antigen.epitope"]

# %% [markdown]
# ## Duplicate CDR3-epitope pairs

# %%
print(f"There were {df_normal.shape[0] - df_normal.drop_duplicates(columns).shape[0]} duplicate CDR3-epitope pairs present in the dataset.")
# Out:
# There were 14609 duplicate CDR3-epitope pairs present in the dataset.

# %% [markdown]
# The number of duplicates in the Aug 2019 release was: 14427.

# %% [markdown]
# The normal file contains more entries, but upon removing duplicates both contain the same amount and the exact same entries. Note however, that the slim version only contains **two** duplicates.

# %%
df_normal.shape
# Out:
# (76164, 55)

# %%
df_slim.shape
# Out:
# (61557, 17)

# %%
df_normal.drop_duplicates(columns).shape
# Out:
# (61555, 55)

# %%
df_slim.drop_duplicates(columns).shape
# Out:
# (61555, 17)

# %%
# check content of unique cdr3 and epitopes separately
assert set(df_slim.drop_duplicates(columns).cdr3.unique()) == set(df_normal.drop_duplicates(columns).cdr3.unique())
assert set(df_slim.drop_duplicates(columns)["antigen.epitope"].unique()) == set(df_normal.drop_duplicates(columns)["antigen.epitope"].unique())

# check content of merged sequence pairs
# assert set(df_slim.drop_duplicates(columns)["cdr3"] + "-" + df_slim.drop_duplicates(columns)["antigen.epitope"]) == set(df_normal.drop_duplicates(columns)["cdr3"] + "-" + df_normal.drop_duplicates(columns)["antigen.epitope"])
assert set(df_slim.drop_duplicates(columns)["merged"]) == set(df_normal.drop_duplicates(columns)["merged"])

# %% [markdown]
# These two duplicates in the slim version are two spurious entries according to the web browser.

# %%
df_slim[df_slim.duplicated(subset=columns)]
# Out:
#       gene           cdr3      species antigen.epitope antigen.gene  \
# 17761  TRA    CASSSVNEQYF  HomoSapiens       NLVPMVATV         pp65
# 49225  TRA  CASSDSRGTEAFF  HomoSapiens       LLWNGPMAV         NS4B
#
#       antigen.species complex.id         v.segm     j.segm  v.end  j.start  \
# 17761             CMV      22868     TRAV9-2*01  TRAJ40*01      2       -1
# 49225             YFV      20649  TRAV14/DV4*01  TRAJ42*01      2       -1
#
#              mhc.a mhc.b mhc.class   reference.id  vdjdb.score  \
# 17761  HLA-A*02:01   B2M      MHCI  PMID:28636592            1
# 49225  HLA-A*02:01   B2M      MHCI  PMID:28103239            0
#
#                         merged
# 17761    CASSSVNEQYF-NLVPMVATV
# 49225  CASSDSRGTEAFF-LLWNGPMAV

# %% [markdown]
# **This suggests that the slim version already had some duplicates removed, but not all of them.**

# %% [markdown]
# The duplicated entries that are unique to the normal version, are duplicated because of values in the columns that are missing from the `slim` version, i.e. cdr3fix, meta data and method columns. E.g. "CASSFGVSYEQYF" is duplicated in the normal version, but not in the slim.

# %%
df_normal.loc[df_normal.cdr3.str.contains("CASSFGVSYEQYF")]
# Out:
#        complex.id gene           cdr3       v.segm      j.segm      species  \
# 74676           0  TRB  CASSFGVSYEQYF  TRBV13-1*01  TRBJ2-1*01  MusMusculus
# 74684           0  TRB  CASSFGVSYEQYF  TRBV13-1*01  TRBJ2-1*01  MusMusculus
# 74689           0  TRB  CASSFGVSYEQYF  TRBV13-1*01  TRBJ2-1*01  MusMusculus
# 74695           0  TRB  CASSFGVSYEQYF  TRBV13-1*01  TRBJ2-1*01  MusMusculus
#
#        mhc.a mhc.b mhc.class antigen.epitope  ... cdr3fix.vEnd  \
# 74676  H-2Kb   B2M      MHCI        RGYVYQGL  ...            4
# 74684  H-2Kb   B2M      MHCI        RGYVYQGL  ...            4
# 74689  H-2Kb   B2M      MHCI        RGYVYQGL  ...            4
# 74695  H-2Kb   B2M      MHCI        RGYVYQGL  ...            4
#
#       cdr3fix.vFixType  cdr3fix.vId  cdr3fix.oldVEnd cdr3fix.oldVFixType  \
# 74676      NoFixNeeded  TRBV13-1*01              NaN                 NaN
# 74684      NoFixNeeded  TRBV13-1*01              NaN                 NaN
# 74689      NoFixNeeded  TRBV13-1*01              NaN                 NaN
# 74695      NoFixNeeded  TRBV13-1*01              NaN                 NaN
#
#       cdr3fix.oldVId cdr3fix.oldJFixType cdr3fix.oldJStart cdr3fix.oldJId  \
# 74676            NaN                 NaN               NaN            NaN
# 74684            NaN                 NaN               NaN            NaN
# 74689            NaN                 NaN               NaN            NaN
# 74695            NaN                 NaN               NaN            NaN
#
#                        merged
# 74676  CASSFGVSYEQYF-RGYVYQGL
# 74684  CASSFGVSYEQYF-RGYVYQGL
# 74689  CASSFGVSYEQYF-RGYVYQGL
# 74695  CASSFGVSYEQYF-RGYVYQGL
#
# [4 rows x 55 columns]

# %%
df_slim.loc[df_slim.cdr3.str.contains("CASSFGVSYEQYF")]
# Out:
#       gene           cdr3      species antigen.epitope antigen.gene  \
# 59917  TRB  CASSFGVSYEQYF  MusMusculus        RGYVYQGL            N
#
#       antigen.species complex.id       v.segm      j.segm  v.end  j.start  \
# 59917             VSV          0  TRBV13-1*01  TRBJ2-1*01      4       -1
#
#        mhc.a mhc.b mhc.class  reference.id  vdjdb.score  \
# 59917  H-2Kb   B2M      MHCI  PMID:9560256            3
#
#                        merged
# 59917  CASSFGVSYEQYF-RGYVYQGL

# %% [markdown]
# ## Spurious sequences
#
# Both versions contain spurious entries. E.g. the two spurious duplicates in the slim version are also present in the normal version.

# %%
df_normal.loc[ (df_normal["cdr3"] == "CASSSVNEQYF") & (df_normal["antigen.epitope"] == "NLVPMVATV")]
# & (df_normal["reference.id"] == "PMID:28636592")
# Out:
#        complex.id gene         cdr3       v.segm      j.segm      species  \
# 52639           0  TRB  CASSSVNEQYF  TRBV12-4*01  TRBJ2-7*01  HomoSapiens
# 52640           0  TRB  CASSSVNEQYF  TRBV12-4*01  TRBJ2-7*01  HomoSapiens
# 57680       21042  TRB  CASSSVNEQYF  TRBV12-3*01  TRBJ2-7*01  HomoSapiens
# 57682       21043  TRB  CASSSVNEQYF  TRBV12-3*01  TRBJ2-7*01  HomoSapiens
# 59352           0  TRB  CASSSVNEQYF    TRBV19*01  TRBJ2-7*01  HomoSapiens
# 59357           0  TRB  CASSSVNEQYF    TRBV19*01  TRBJ2-7*01  HomoSapiens
# 64091       22868  TRA  CASSSVNEQYF   TRAV9-2*01   TRAJ40*01  HomoSapiens
#
#              mhc.a mhc.b mhc.class antigen.epitope  ... cdr3fix.vEnd  \
# 52639  HLA-A*02:01   B2M      MHCI       NLVPMVATV  ...            4
# 52640  HLA-A*02:01   B2M      MHCI       NLVPMVATV  ...            4
# 57680  HLA-A*02:01   B2M      MHCI       NLVPMVATV  ...            4
# 57682  HLA-A*02:01   B2M      MHCI       NLVPMVATV  ...            4
# 59352  HLA-A*02:01   B2M      MHCI       NLVPMVATV  ...            4
# 59357  HLA-A*02:01   B2M      MHCI       NLVPMVATV  ...            4
# 64091  HLA-A*02:01   B2M      MHCI       NLVPMVATV  ...            2
#
#       cdr3fix.vFixType  cdr3fix.vId  cdr3fix.oldVEnd cdr3fix.oldVFixType  \
# 52639      NoFixNeeded  TRBV12-4*01              NaN                 NaN
# 52640      NoFixNeeded  TRBV12-4*01              NaN                 NaN
# 57680      NoFixNeeded  TRBV12-3*01              NaN                 NaN
# 57682      NoFixNeeded  TRBV12-3*01              NaN                 NaN
# 59352      NoFixNeeded    TRBV19*01              NaN                 NaN
# 59357      NoFixNeeded    TRBV19*01              NaN                 NaN
# 64091      NoFixNeeded   TRAV9-2*01              NaN                 NaN
#
#       cdr3fix.oldVId cdr3fix.oldJFixType cdr3fix.oldJStart cdr3fix.oldJId  \
# 52639            NaN                 NaN               NaN            NaN
# 52640            NaN                 NaN               NaN            NaN
# 57680            NaN                 NaN               NaN            NaN
# 57682            NaN                 NaN               NaN            NaN
# 59352            NaN                 NaN               NaN            NaN
# 59357            NaN                 NaN               NaN            NaN
# 64091            NaN                 NaN               NaN            NaN
#
#                       merged
# 52639  CASSSVNEQYF-NLVPMVATV
# 52640  CASSSVNEQYF-NLVPMVATV
# 57680  CASSSVNEQYF-NLVPMVATV
# 57682  CASSSVNEQYF-NLVPMVATV
# 59352  CASSSVNEQYF-NLVPMVATV
# 59357  CASSSVNEQYF-NLVPMVATV
# 64091  CASSSVNEQYF-NLVPMVATV
#
# [7 rows x 55 columns]

# %%
df_normal.loc[ (df_normal["cdr3"] == "CASSDSRGTEAFF") & (df_normal["antigen.epitope"] == "LLWNGPMAV")]
# & (df_normal["reference.id"] == "PMID:28103239")
# Out:
#        complex.id gene           cdr3         v.segm      j.segm      species  \
# 52955       20649  TRA  CASSDSRGTEAFF  TRAV14/DV4*01   TRAJ42*01  HomoSapiens
# 52956       20649  TRB  CASSDSRGTEAFF       TRBV9*01  TRBJ1-1*01  HomoSapiens
#
#              mhc.a mhc.b mhc.class antigen.epitope  ... cdr3fix.vEnd  \
# 52955  HLA-A*02:01   B2M      MHCI       LLWNGPMAV  ...            2
# 52956  HLA-A*02:01   B2M      MHCI       LLWNGPMAV  ...            4
#
#       cdr3fix.vFixType    cdr3fix.vId  cdr3fix.oldVEnd cdr3fix.oldVFixType  \
# 52955      NoFixNeeded  TRAV14/DV4*01              NaN                 NaN
# 52956      NoFixNeeded       TRBV9*01              NaN                 NaN
#
#       cdr3fix.oldVId cdr3fix.oldJFixType cdr3fix.oldJStart cdr3fix.oldJId  \
# 52955            NaN                 NaN               NaN            NaN
# 52956            NaN                 NaN               NaN            NaN
#
#                         merged
# 52955  CASSDSRGTEAFF-LLWNGPMAV
# 52956  CASSDSRGTEAFF-LLWNGPMAV
#
# [2 rows x 55 columns]

# %% [markdown]
# The spurious entries in the normal dataset can be retrieved by filtering on the `cdr3fix.good` property.
#
# **However, note that the VDJdb web browser has two separate checkboxes for spurious entries, namely `Include non-canonical` and `Include unmapped V/J`. So an additional filter might be required, unless `cdr3fix.good` is already a summary of these other properties (EDIT: this does seem to be the case).**

# %% [markdown]
# As of the August 7th 2019 release, selecting all species and TCR chains in the VDJdb browser, while excluding the spurious entries, results in 73224 out of 75474 entries, i.e. **2250 entries are labeled as spurious**.

# %% [markdown]
# This number does correspond to a filtering on the `cdr3fix.good` property in the normal file.

# %%
df_normal.loc[~df_normal["cdr3fix.good"]].shape
# Out:
# (2265, 55)

# %% [markdown]
# Some of the spurious entries are also duplicated.

# %%
df_normal.loc[~df_normal["cdr3fix.good"]].drop_duplicates(columns).shape
# Out:
# (2025, 55)

# %% [markdown]
# All spurious entries are contained in the slim file.

# %%
set(df_normal.loc[~df_normal["cdr3fix.good"], "merged"]).issubset(set(df_slim["merged"]))
# Out:
# True

# %%
set(df_normal.loc[~df_normal["cdr3fix.good"], "merged"]) - set(df_slim["merged"])
# Out:
# set()

# %%
all(df_normal.loc[~df_normal["cdr3fix.good"], "merged"].isin(df_slim["merged"]))
# Out:
# True

# %% [markdown]
# The spurious sequences are also in the duplicated subset of the slim file. In other words, the two duplicates in the slim set, do occur in the spurious sequences of the normal file.

# %%
any(df_normal.loc[~df_normal["cdr3fix.good"], "merged"].isin(df_slim.loc[df_slim["merged"].duplicated(), "merged"]))
# Out:
# True

# %%
df_slim.loc[df_slim["merged"].duplicated(), "merged"]
# Out:
# 17761      CASSSVNEQYF-NLVPMVATV
# 49225    CASSDSRGTEAFF-LLWNGPMAV
# Name: merged, dtype: object

# %%
df_slim.loc[df_slim["merged"].duplicated(), "merged"].apply(
    lambda x: df_normal.loc[~df_normal["cdr3fix.good"], "merged"].str.contains(x).any())
# Out:
# 17761    True
# 49225    True
# Name: merged, dtype: bool

# %%
df_slim.loc[df_slim["merged"].duplicated(), "merged"].apply(
    lambda x: x in df_normal.loc[~df_normal["cdr3fix.good"], "merged"].values)
# Out:
# 17761    True
# 49225    True
# Name: merged, dtype: bool

# %%
#any(df_normal.loc[~df_normal["cdr3fix.good"], "merged"].apply(lambda x: x in df_slim[df_slim["merged"].duplicated()].values))

# %% [markdown]
# The above checks do not completely guarantee that the spurious sequences are in the slim file, because it is possible that a spurious sequence, made up of sequences A and B, is a duplicate, and its duplicate entry with sequences A and B is not spurious.
#
# To check this, all non-duplicate spurious sequences in the normal file should be compared to the slim set, plus all entries in the slim set that occur in the spurious subset of the normal file, should be checked for duplicates.

# %%
non_dup_spurious = df_normal.loc[ (~df_normal.duplicated(subset="merged")) & (~df_normal["cdr3fix.good"]), "merged"]
print(f"{non_dup_spurious.shape[0]} out of {df_normal.loc[~df_normal['cdr3fix.good']].shape[0]} entries are spurious and do not have duplicates in the original file.")
# Out:
# 1995 out of 2265 entries are spurious and do not have duplicates in the original file.

# %%
set(non_dup_spurious).issubset(set(df_slim["merged"]))
# Out:
# True

# %% [markdown]
# Some more tests...

# %%
df_normal.shape
# Out:
# (76164, 55)

# %%
df_normal.drop_duplicates(columns).shape
# Out:
# (61555, 55)

# %%
df_normal[df_normal["cdr3fix.good"]].shape
# Out:
# (73899, 55)

# %%
df_normal[df_normal["cdr3fix.good"]].drop_duplicates(columns).shape
# Out:
# (59566, 55)

# %%
df_slim.shape
# Out:
# (61557, 17)

# %%
df_slim.drop_duplicates(columns).shape
# Out:
# (61555, 17)

# %%
df_slim[df_slim["merged"].isin(df_normal.loc[df_normal["cdr3fix.good"], "merged"])].drop_duplicates(columns).shape
# Out:
# (59566, 17)

# %% [markdown]
# ---

# %% [markdown]
# Check confidence scores of spurious entries and compare these to the two spurious/duplicate entries in the slim version.

# %%
df_normal[~df_normal["cdr3fix.good"]].groupby("vdjdb.score").size()
# Out:
# vdjdb.score
# 0    1873
# 1     254
# 2      89
# 3      49
# dtype: int64

# %% [markdown]
# # Comparison of VDJdb web export and GitHub Release Aug

# %%
# load august release (same date as web export)
vdjdb_slim_path_aug = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2019-08-08/vdjdb.slim.txt"
df_slim_aug = pd.read_csv(vdjdb_slim_path_aug, sep="\t")

vdjdb_normal_path_aug = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2019-08-08/vdjdb.txt"
df_normal_aug = pd.read_csv(vdjdb_normal_path_aug, sep="\t")
# expand the json/dict-like columns
df_normal_aug = (
    df_normal_aug.join(json_normalize(df_normal_aug["method"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("method."))
    .join(json_normalize(df_normal_aug["meta"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("meta."))
    .join(json_normalize(df_normal_aug["cdr3fix"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("cdr3fix."))
    .drop(["method", "meta", "cdr3fix"], axis=1)
)
columns = ["cdr3", "antigen.epitope"]

# create column based on cdr3 and epitope sequences
df_normal_aug["merged"] = df_normal_aug["cdr3"] + "-" + df_normal_aug["antigen.epitope"]
df_slim_aug["merged"] = df_slim_aug["cdr3"] + "-" + df_slim_aug["antigen.epitope"]

# load web export
vdjdb_web_path = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-browser.tsv"
df_web = pd.read_csv(vdjdb_web_path, sep="\t")
columns_web = ["CDR3", "Epitope"]

# create column based on cdr3 and epitope sequences
df_web["merged"] = df_web["CDR3"] + "-" + df_web["Epitope"]

# %% [markdown]
# ## Comparison of spurious sequences and VDJdb web dataset
# ### The web version is equal to the GitHub release (normal) after filtering on cdr3fix.good

# %% [markdown]
# The spurious entries in the normal make up the entire difference with the VDJdb web dataset (using the filtering options stated earlier).

# %% [markdown]
# Same size:

# %%
# check size after duplicate removal
assert df_normal_aug.loc[df_normal_aug["cdr3fix.good"]].drop_duplicates(columns).shape[0] == \
    df_web.drop_duplicates(columns_web).shape[0]

# %% [markdown]
# And some content:

# %%
# check contents after removing spurious sequences
assert set(df_normal_aug.loc[df_normal_aug["cdr3fix.good"], "merged"]) == set(df_web["merged"])

# %% [markdown]
# ## Web versus slim

# %% [markdown]
# ## The slim GitHub release still contains duplicated and spurious sequences

# %% [markdown]
# The web version contains fewer entries after deduplication, which indicates that the slim version still contains some spurious sequences.

# %%
print(df_web.shape)
print(df_web.drop_duplicates(columns_web).shape)
# Out:
# (73224, 18)
# (59072, 18)

# %%
print(df_slim.shape)
print(df_slim.drop_duplicates(columns).shape)
# Out:
# (61557, 17)
# (61555, 17)

# %%
slim_minus_web = set(df_slim_aug["merged"]) - set(df_web["merged"])
print(f"The slim set contains {len(slim_minus_web)} additional unique sequences over the web export")
# Out:
# The slim set contains 1975 additional unique sequences over the web export

# %% [markdown]
# These entries are all found in the spurious entries set of the normal file.

# %%
slim_minus_web.issubset(set(df_normal_aug.loc[~df_normal_aug["cdr3fix.good"], "merged"]))
# Out:
# True

# %% [markdown]
# # In-depth statistics and figures for the VDJdb GitHub January 2020 release (after filtering)
#
# What follows is a description of the contents of the `vdjdb.txt` file in the Aug 2018 GitHub release after removing all spurious and duplicate entries, and performing the same filtering steps as for the data used to train the neural networks (i.e. focusing only on human TRB entries).
#
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_palette("Set1")
sns.set_style('darkgrid')
# plt.rc('patch', edgecolor="0.2", linewidth=.8, alpha=.75)
plt.rcParams['patch.edgecolor'] = '0.2'
plt.rcParams['patch.linewidth'] = '.8'
# plt.rcParams['patch.alpha'] = '.75'
# plt.rcParams['figure.figsize'] = (12, 8)

# sns.set_palette("Set1", n_colors=8, desat=.5)
# sns.set_palette("colorblind")

# set font style
plt.rcParams.update({'font.size': 10})
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = "Source Sans Pro" #['Fira Sans', 'Source Sans Pro']
font = {'weight' : 'normal'}#,'size'   : 22}

# %%
# import dataset again to start fresh
vdjdb_normal_path = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt"
df = pd.read_csv(vdjdb_normal_path, sep="\t")

# expand the json/dict-like columns
df = (
    df.join(json_normalize(df["method"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("method."))
    .join(json_normalize(df["meta"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("meta."))
    .join(json_normalize(df["cdr3fix"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("cdr3fix."))
    .drop(["method", "meta", "cdr3fix"], axis=1)
)

columns = ["cdr3", "antigen.epitope"]

# create column based on cdr3 and epitope sequences
df["merged"] = df["cdr3"] + "-" + df["antigen.epitope"]

# create length columns for figures
df["cdr3.len"] = df["cdr3"].str.len()
df["antigen.epitope.len"] = df["antigen.epitope"].str.len()

# %% [markdown]
# The VDJdb contains a number of duplicates, since there are not relevant for our machine learning model, they are removed entirely. **Duplicates are defined as entries which share the same CDR3 and epitope sequence.**

# %%
# deduplicate main dataframe
df_dedup = df.drop_duplicates(columns)

# %%
print(f"There were {df.shape[0] - df_dedup.shape[0]} duplicate CDR3-epitope pairs present in the dataset.")
# Out:
# There were 14609 duplicate CDR3-epitope pairs present in the dataset.

# %%
df_dedup.columns
# Out:
# Index(['complex.id', 'gene', 'cdr3', 'v.segm', 'j.segm', 'species', 'mhc.a',
#        'mhc.b', 'mhc.class', 'antigen.epitope', 'antigen.gene',
#        'antigen.species', 'reference.id', 'vdjdb.score', 'web.method',
#        'web.method.seq', 'web.cdr3fix.nc', 'web.cdr3fix.unmp',
#        'method.frequency', 'method.identification', 'method.sequencing',
#        'method.singlecell', 'method.verification', 'meta.cell.subset',
#        'meta.clone.id', 'meta.donor.MHC', 'meta.donor.MHC.method',
#        'meta.epitope.id', 'meta.replica.id', 'meta.samples.found',
#        'meta.structure.id', 'meta.studies.found', 'meta.study.id',
#        'meta.subject.cohort', 'meta.subject.id', 'meta.tissue', 'cdr3fix.cdr3',
#        'cdr3fix.cdr3_old', 'cdr3fix.fixNeeded', 'cdr3fix.good',
#        'cdr3fix.jCanonical', 'cdr3fix.jFixType', 'cdr3fix.jId',
#        'cdr3fix.jStart', 'cdr3fix.vCanonical', 'cdr3fix.vEnd',
#        'cdr3fix.vFixType', 'cdr3fix.vId', 'cdr3fix.oldVEnd',
#        'cdr3fix.oldVFixType', 'cdr3fix.oldVId', 'cdr3fix.oldJFixType',
#        'cdr3fix.oldJStart', 'cdr3fix.oldJId', 'merged', 'cdr3.len',
#        'antigen.epitope.len'],
#       dtype='object')

# %% [markdown]
# ## Statistics for all data (all species)

# %%
# plt.rcParams.update(plt.rcParamsDefault)

# %%
ax = sns.countplot(x="gene", data=df_dedup, alpha=.85)
ax.set_title('Distribution of TRA and TRB chains')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df_dedup.columns
# Out:
# Index(['complex.id', 'gene', 'cdr3', 'v.segm', 'j.segm', 'species', 'mhc.a',
#        'mhc.b', 'mhc.class', 'antigen.epitope', 'antigen.gene',
#        'antigen.species', 'reference.id', 'vdjdb.score', 'web.method',
#        'web.method.seq', 'web.cdr3fix.nc', 'web.cdr3fix.unmp',
#        'method.frequency', 'method.identification', 'method.sequencing',
#        'method.singlecell', 'method.verification', 'meta.cell.subset',
#        'meta.clone.id', 'meta.donor.MHC', 'meta.donor.MHC.method',
#        'meta.epitope.id', 'meta.replica.id', 'meta.samples.found',
#        'meta.structure.id', 'meta.studies.found', 'meta.study.id',
#        'meta.subject.cohort', 'meta.subject.id', 'meta.tissue', 'cdr3fix.cdr3',
#        'cdr3fix.cdr3_old', 'cdr3fix.fixNeeded', 'cdr3fix.good',
#        'cdr3fix.jCanonical', 'cdr3fix.jFixType', 'cdr3fix.jId',
#        'cdr3fix.jStart', 'cdr3fix.vCanonical', 'cdr3fix.vEnd',
#        'cdr3fix.vFixType', 'cdr3fix.vId', 'cdr3fix.oldVEnd',
#        'cdr3fix.oldVFixType', 'cdr3fix.oldVId', 'cdr3fix.oldJFixType',
#        'cdr3fix.oldJStart', 'cdr3fix.oldJId', 'merged', 'cdr3.len',
#        'antigen.epitope.len'],
#       dtype='object')

# %%
ax = sns.countplot(x="gene", hue="mhc.class", data=df_dedup, alpha=.85)
ax.set_title('Distribution of TRA and TRB chains per MHC class')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = sns.countplot(x="gene", hue="species", data=df_dedup, alpha=.85)
ax.set_title('Distribution of TRA and TRB chains per host species')
ax.set_ylabel('Count')
plt.legend(title='Species', loc='upper right')#, labels=['Homo Sapiens', 'Mus Musculus', 'Macaca Mulatta'])

# %%
ax = sns.countplot(x="species", hue="gene", data=df_dedup, alpha=.85)
ax.set_title('Distribution of TRA and TRB chains per host species')
ax.set_ylabel('Count')
plt.legend(title='Chain', loc='upper right')#, labels=['TRA', 'TRB'])

# %%
plt.xticks(rotation=90)
ax = sns.countplot(x="mhc.a", hue="mhc.class", data=df_dedup, alpha=.85,
#                   color=sns.color_palette("Set1")[1]
                  )
ax.set_title('Distribution of MHC alpha chains')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.xticks(rotation=90)
ax = sns.countplot(x="mhc.a", hue="mhc.class", data=df_dedup, alpha=.85,
                order=df_dedup["mhc.a"].value_counts().index,
#                   color=sns.color_palette("Set1")[1]
                  )
ax.set_title('Distribution of MHC alpha chains')
ax.set_ylabel('Count')
plt.legend(title='Chain', loc='upper right', labels=['MHCI', 'MHCII'])

# %%
plt.xticks(rotation=90)
ax = sns.countplot(x="mhc.a", hue="species", data=df_dedup, alpha=.85)
ax.set_title('Distribution of MHC alpha chains')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = sns.countplot(x="mhc.a", hue="species", 
                   order=df_dedup["mhc.a"].value_counts().iloc[:5].index, 
                   data=df_dedup, alpha=.75)

# %%
ax = sns.countplot(x="mhc.a", 
                   order=df_dedup["mhc.a"].value_counts().iloc[:9].index, 
                   data=df_dedup, alpha=.8)

# %%
# todo: MHC plot, but sort by common frequency across species, then color depending on species origin

# %%
plt.figure()#figsize=(20,15))
ax = sns.countplot(x="mhc.a", 
                   order=df_dedup["mhc.a"].value_counts().iloc[:9].index, 
                   color=sns.color_palette("Set1")[0], 
                   data=df_dedup, alpha=.8)

# %% [markdown]
# ## Human CDR3-epitope pairs
#
# - Duplicates removed (last operation)
# - Spurious sequences removed
# - Only human
# - Both TRB/TRA chains

# %%
# Human pairs
df_human = df.loc[ (df["species"] == "HomoSapiens") & (df["cdr3fix.good"]) ]
df_human = df_human.drop_duplicates(columns)

# also read in the data using the preprocessing script once, since it performs various checks
df_test = preprocess_vdjdb.filter_vdjdb(vdjdb_normal_path, tcr_chain="all", species="human", drop_spurious=True, mhc="all", hla="all")
assert df_test.equals(df_human[columns])

# %%
ax = sns.countplot(x="gene", data=df_human, alpha=.8)
ax.set_title('Distribution of CDR3 chains in human entries (non-spurious)')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = sns.countplot(x="mhc.a", 
                   order=df_human["mhc.a"].value_counts().iloc[:5].index, 
                   data=df_human, alpha=.8)
ax.set_title('Distribution of MHC alpha chains in human entries (non-spurious)')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# epitope length
# plt.figure(figsize=(15,10))
ax = sns.countplot(x="antigen.epitope.len", data=df_human, hue="gene",
#                    order=df_human["antigen.epitope.len"].value_counts().iloc[:5].index,
                   alpha=.8)
ax.set_title('Epitope length distribution per CDR3 chain in human entries (non-spurious)')
ax.set_ylabel('Count')
ax.set_xlabel('Epitope length')
plt.legend(title='Chain', loc='upper right')

# %%
# cdr3 length
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="cdr3.len", data=df_human, hue="gene", alpha=.8)
ax.set_title('CDR3 length distribution per chain in human entries (non-spurious)')
ax.set_ylabel('Count')
ax.set_xlabel('CDR3 length')
plt.legend(title='Chain', loc='upper right')

# %%
# cdr3 length
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="cdr3.len", hue="mhc.class", data=df_human,
                   alpha=.8)
ax.set_title('CDR3 length distribution per MHC class in human entries (non-spurious)')
ax.set_ylabel('Count')
ax.set_xlabel('CDR3 length')
plt.legend(title='MHC class', loc='upper right')

# %%
# pairs per epitope

# df_human.groupby("antigen.epitope").size()
df_human["antigen.epitope"].value_counts()
# Out:
# KLGGALQAK     24041
# NLVPMVATV      6514
# GILGFVFTL      6389
# AVFDRKSDAK     3175
# ELAGIGILTV     1624
#               ...
# LLFGPVYV          1
# LGYGFVNYI         1
# MLWGYLQYV         1
# LLFGYPVAV         1
# ELAAIGILTV        1
# Name: antigen.epitope, Length: 186, dtype: int64

# %%
fig, ax = plt.subplots()#figsize=(10,5))
plt.xticks(rotation=45, ha="right")
sns.countplot(ax=ax, x='antigen.epitope', 
                   order=df_human["antigen.epitope"].value_counts().iloc[:20].index, 
                   data=df_human, 
                   edgecolor=".2", linewidth=.5, alpha=.75, color=sns.color_palette("Set1")[1])
plt.show()

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=90)
ax = sns.countplot(x="antigen.epitope", hue="gene",
                   order=df_human["antigen.epitope"].value_counts().iloc[:20].index, 
                   data=df_human, 
                   edgecolor=".2", linewidth=.5, alpha=.75, color=sns.color_palette("Set1")[1])
ax.set_title('Epitope distribution per CDR3 chain in human entries (non-spurious)')
ax.set_ylabel('Count')
ax.set_xlabel('Epitope')
plt.legend(title='Chain', loc='upper right')

# %% [markdown]
# ## Human TRB CDR3-epitope pairs
#
# - Duplicates removed (last operation)
# - Spurious sequences removed
# - Only human
# - Only TRB CDR3 sequences

# %%
# Human TRRB
# DONT DO THIS IN REVERSE ORDER: some entries appear to be duplicate pairs, but with differing chain / fix / species
df_human_trb = df.loc[ (df["species"] == "HomoSapiens") & (df["gene"] == "TRB") & (df["cdr3fix.good"]) ]
df_human_trb = df_human_trb.drop_duplicates(columns)

# also read in the data using the preprocessing script once, since it performs various checks
df_test = preprocess_vdjdb.filter_vdjdb(vdjdb_normal_path, tcr_chain="TRB", species="human", drop_spurious=True, mhc="all", hla="all")
assert df_test.equals(df_human_trb[columns])

# %%
ax = sns.countplot(x="mhc.a", 
                   order=df_human_trb["mhc.a"].value_counts().iloc[:5].index, 
                   data=df_human_trb, 
                   alpha=.75)

# %%
# epitope length
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="antigen.epitope.len", data=df_human_trb,
#                    order=df_human["antigen.epitope.len"].value_counts().iloc[:5].index,
                   alpha=.75)

# %%
# cdr3 length
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="cdr3.len", data=df_human_trb,
                   alpha=.75)

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=45, ha="right")
ax = sns.countplot(x="antigen.epitope",
                   order=df_human_trb["antigen.epitope"].value_counts().iloc[:20].index, 
                   data=df_human_trb, 
                   alpha=.75, 
                   color=sns.color_palette("Set1")[1])

# %%
df_human_trb["antigen.epitope"].value_counts()
# Out:
# KLGGALQAK         12615
# NLVPMVATV          4421
# GILGFVFTL          3385
# AVFDRKSDAK         1641
# ELAGIGILTV         1292
#                   ...
# LPEPLPQGGLTAY         1
# PKYVKQNTLKLAR         1
# EAAGIGILTV            1
# GPEPLPQGQLTAY         1
# VHFFKNIVTPRTPG        1
# Name: antigen.epitope, Length: 184, dtype: int64

# %% [markdown]
# The over-abundant `KLGGALQAK` epitope makes up almost 40% of the human TRB unique data.

# %%
12615/df_human_trb.shape[0]
# Out:
# 0.3849087691462745

# %% [markdown]
# ## 10x data exploration

# %%
df_human_trb_10x_only = df.loc[(df["species"] == "HomoSapiens") & 
                          (df["gene"] == "TRB") & 
                          (df["cdr3fix.good"]) & 
                          (df["reference.id"].str.contains("10x"))]
df_human_trb_10x_only.groupby("antigen.epitope").size().sort_values(ascending=False)
# Out:
# antigen.epitope
# KLGGALQAK      13921
# AVFDRKSDAK      1750
# GILGFVFTL       1339
# RAKFKQLL        1234
# IVTDFSVIK        718
# RLRAEAQVK        430
# ELAGIGILTV       328
# GLCTLVAML        137
# RTLNAWVKV         47
# AYAQKIFKI         39
# FLYALALLL         38
# SLFNTVATLY        38
# FLASKIGRLV        34
# LLFGYPVYV         34
# LLDFVRFMGV        26
# FLRGRAYGL         23
# KTWGQYWQV         16
# CYTWNQMNL         15
# QYDPVAALF         14
# MLDLQPETT         14
# YLLEMLWRL         13
# IMDQVPFSV         12
# KVLEYVIKV          8
# YLNDHLEPWI         7
# IPSINVHHY          7
# CLLWSFQTSA         7
# RMFPNAPYL          7
# SLLMWITQV          6
# SLFNTVATL          5
# QPRAPIRPI          5
# CLLGTYTQDV         3
# RPPIFIRRL          3
# ELRRKMMYM          2
# SLYNTVATLY         2
# NLVPMVATV          2
# KLQCVDLHV          1
# RPHERNGFTVL        1
# ILKEPVHGV          1
# TPRVTGGGAM         1
# RIAAWMATY          1
# VTEHDTLLY          1
# KVAELVHFL          1
# dtype: int64

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=45)
ax = sns.countplot(x="antigen.epitope",
                   order=df_human_trb_10x_only["antigen.epitope"].value_counts().iloc[:20].index, 
                   data=df_human_trb_10x_only,
                   alpha=.75, 
                   color=sns.color_palette("Set1")[1])

# %% [markdown]
# Which epitopes occur exclusively in the 10x data?

# %%
import numpy as np
df_human_trb_10x_only["antigen.epitope"].unique()[~np.isin(df_human_trb_10x_only["antigen.epitope"].unique(),
                         df.loc[(df["species"] == "HomoSapiens") & 
                          (df["gene"] == "TRB") & 
                          (df["cdr3fix.good"]) & 
                          ~(df["reference.id"].str.contains("10x"))]
       )
]
# Out:
# array(['KLGGALQAK', 'CYTWNQMNL', 'RIAAWMATY', 'SLFNTVATLY', 'RLRAEAQVK',
#        'LLDFVRFMGV', 'AYAQKIFKI', 'FLYALALLL', 'FLASKIGRLV', 'MLDLQPETT',
#        'IMDQVPFSV', 'YLLEMLWRL', 'KVLEYVIKV', 'RTLNAWVKV', 'KTWGQYWQV',
#        'YLNDHLEPWI', 'QPRAPIRPI', 'SLFNTVATL', 'CLLWSFQTSA', 'CLLGTYTQDV',
#        'KVAELVHFL', 'SLYNTVATLY', 'KLQCVDLHV'], dtype=object)

# %%
"KLGGALQAK" in df.loc[(df["species"] == "HomoSapiens") & 
                          (df["gene"] == "TRB") & 
                          (df["cdr3fix.good"]) & 
                          ~(df["reference.id"].str.contains("10x")), "antigen.epitope"].values
# Out:
# False

# %% [markdown]
# Which epitopes do occur in both the 10x and non-10x data?

# %%
df_human_trb_10x_only["antigen.epitope"].unique()[np.isin(df_human_trb_10x_only["antigen.epitope"].unique(),
                         df.loc[(df["species"] == "HomoSapiens") & 
                          (df["gene"] == "TRB") & 
                          (df["cdr3fix.good"]) & 
                          ~(df["reference.id"].str.contains("10x"))]
       )
]
# Out:
# array(['ELAGIGILTV', 'IVTDFSVIK', 'AVFDRKSDAK', 'RAKFKQLL', 'GILGFVFTL',
#        'RMFPNAPYL', 'GLCTLVAML', 'LLFGYPVYV', 'SLLMWITQV', 'IPSINVHHY',
#        'QYDPVAALF', 'FLRGRAYGL', 'TPRVTGGGAM', 'ILKEPVHGV', 'RPHERNGFTVL',
#        'RPPIFIRRL', 'NLVPMVATV', 'VTEHDTLLY', 'ELRRKMMYM'], dtype=object)

# %% [markdown]
# ## Removing over-abundant 10x data entries

# %%
# read in data again from scratch, because duplicate removal before additional filtering can mess up the results
# Human TRB 10x
df_human_trb_10xKLGGALQAK = df.loc[(df["species"] == "HomoSapiens") & 
                                   (df["gene"] == "TRB") & 
                                   (df["cdr3fix.good"]) ]
# df_human_trb_10x = df_human_trb_10x.drop_duplicates(columns) # do this after removing everything else

# %% [markdown]
# The over-abundant `KLGGALQAK` epitope originates **entirely** from the 10xgenomics data.

# %%
# df_human_trb.loc[df_human_trb["reference.id"].str.contains("10xgenomics.com")]
df_human_trb_10xKLGGALQAK.loc[df_human_trb_10xKLGGALQAK["reference.id"] == "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#"].shape
# Out:
# (20291, 57)

# %%
df_human_trb_10xKLGGALQAK.loc[df_human_trb_10xKLGGALQAK["reference.id"] == "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#"].groupby("antigen.epitope").size().sort_values(ascending=False)
df_human_trb_10xKLGGALQAK.loc[df_human_trb_10xKLGGALQAK["reference.id"] == \
                 "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#",\
                 "antigen.epitope"].value_counts()[:10]
# Out:
# KLGGALQAK     13921
# AVFDRKSDAK     1750
# GILGFVFTL      1339
# RAKFKQLL       1234
# IVTDFSVIK       718
# RLRAEAQVK       430
# ELAGIGILTV      328
# GLCTLVAML       137
# RTLNAWVKV        47
# AYAQKIFKI        39
# Name: antigen.epitope, dtype: int64

# %% [markdown]
# **All of the `KLGGALQAK` entries are derived from the 10x source.**

# %%
assert df_human_trb_10xKLGGALQAK.loc[ (df_human_trb_10xKLGGALQAK["antigen.epitope"] == "KLGGALQAK") ].shape[0] == \
        df_human_trb_10xKLGGALQAK.loc[ (df_human_trb_10xKLGGALQAK["antigen.epitope"] == "KLGGALQAK") & (df_human_trb_10xKLGGALQAK["reference.id"] == \
                 "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#")].shape[0]

# %%
df_human_trb_10xKLGGALQAK.loc[(df_human_trb_10xKLGGALQAK["antigen.epitope"] == "KLGGALQAK")].groupby("reference.id").size()
# Out:
# reference.id
# https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#    13921
# dtype: int64

# %% [markdown]
# Removing this epitope, and then filtering out any remaining duplicates, results in the following statistics:

# %%
df_human_trb_10xKLGGALQAK = df_human_trb_10xKLGGALQAK.loc[~ (df_human_trb_10xKLGGALQAK["antigen.epitope"] == "KLGGALQAK") |
                 ~ (df_human_trb_10xKLGGALQAK["reference.id"] == \
                 "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#") ]
df_human_trb_10xKLGGALQAK = df_human_trb_10xKLGGALQAK.drop_duplicates(columns)

# %%
df_human_trb_10xKLGGALQAK.shape
# Out:
# (20159, 57)

# %%
# also read in the data using the preprocessing script once, since it performs various checks
df_test = preprocess_vdjdb.filter_vdjdb(vdjdb_normal_path, tcr_chain="TRB", species="human", 
                                        specific_removal_epitope_reference=["KLGGALQAK", "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#"], 
                                        drop_spurious=True, mhc="all", hla="all")
assert df_test.equals(df_human_trb_10xKLGGALQAK[columns])

# %%
ax = sns.countplot(x="mhc.a", 
                   order=df_human_trb_10xKLGGALQAK["mhc.a"].value_counts().iloc[:5].index, 
                   data=df_human_trb_10xKLGGALQAK, alpha=.8)

# %%
# epitope length
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="antigen.epitope.len", data=df_human_trb_10xKLGGALQAK,
#                    order=df_human_trb_10xKLGGALQAK["antigen.epitope.len"].value_counts().iloc[:5].index,
                   alpha=.8)
ax.set_title('Epitope length distribution in human TRB entries (non-spurious, no 10x data)')
ax.set_ylabel('Count')
ax.set_xlabel('Epitope length')
# Out:
# Text(0.5, 0, 'Epitope length')

# %%
# epitope length per mhc
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="antigen.epitope.len", hue="mhc.class", data=df_human_trb_10xKLGGALQAK,
#                    order=df_human_trb_10xKLGGALQAK["antigen.epitope.len"].value_counts().iloc[:5].index,
                   alpha=.8)
ax.set_title('Epitope length distribution per MHC class in human TRB entries (non-spurious, no 10x data)')
ax.set_ylabel('Count')
ax.set_xlabel('Epitope length')
plt.legend(title='MHC class', loc='upper right')

# %%
# cdr3 length
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="cdr3.len", data=df_human_trb_10xKLGGALQAK,
                   alpha=.8)
ax.set_title('CDR3 length distribution in human TRB entries (non-spurious, no 10x data)')
ax.set_ylabel('Count')
ax.set_xlabel('CDR3 length')
# Out:
# Text(0.5, 0, 'CDR3 length')

# %%
# cdr3 length
plt.figure()#figsize=(15,10))
ax = sns.countplot(x="cdr3.len", hue="mhc.class", data=df_human_trb_10xKLGGALQAK,
                   alpha=.8)
ax.set_title('CDR3 length distribution per MHC class in human TRB entries (non-spurious, no 10x data)')
ax.set_ylabel('Count')
ax.set_xlabel('CDR3 length')
plt.legend(title='MHC class', loc='upper right')

# %% [markdown]
# The number of MHCII entries is a lot lower after removing the overabundant 10x epitope.

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=45)
ax = sns.countplot(x="antigen.epitope",
                   order=df_human_trb_10xKLGGALQAK["antigen.epitope"].value_counts().iloc[:20].index, 
                   data=df_human_trb_10xKLGGALQAK, 
                   edgecolor=".2", linewidth=.5, alpha=.75, color=sns.color_palette("Set1")[1])

# %% [markdown]
# ## How much data is lost due to filtering on spurious entries?

# %% [markdown]
# Only a few hundred entries are omitted when filtering on spurious entries.

# %%
df_human_trb_10xKLGGALQAK = df.loc[ (df["species"] == "HomoSapiens") & (df["gene"] == "TRB") & (df["cdr3fix.good"]) ]
df_human_trb_10xKLGGALQAK = df_human_trb_10xKLGGALQAK.loc[~ (df_human_trb_10xKLGGALQAK["antigen.epitope"] == "KLGGALQAK") |
                 ~ (df_human_trb_10xKLGGALQAK["reference.id"] == \
                 "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#") ]
df_human_trb_10xKLGGALQAK.drop_duplicates(columns).shape
# Out:
# (20159, 57)

# %%
df_human_trb_10xKLGGALQAK_withspurious = df.loc[ (df["species"] == "HomoSapiens") & (df["gene"] == "TRB") ]
df_human_trb_10xKLGGALQAK_withspurious = df_human_trb_10xKLGGALQAK_withspurious.loc[~ (df_human_trb_10xKLGGALQAK_withspurious["antigen.epitope"] == "KLGGALQAK") |
                 ~ (df_human_trb_10xKLGGALQAK_withspurious["reference.id"] == \
                 "https://www.10xgenomics.com/resources/application-notes/a-new-way-of-exploring-immunity-linking-highly-multiplexed-antigen-recognition-to-immune-repertoire-and-phenotype/#") ]
df_human_trb_10xKLGGALQAK_withspurious.drop_duplicates(columns).shape
# Out:
# (20494, 57)

# %% [markdown]
# # Create figures for filtered data (including length restrictions)

# %% [markdown]
# Currently, the length restrictions happen during the training step, so in order to get accurate statistics on the dataset these have to be excluded manually first.

# %%
df_human_no10x = df.loc[(df["species"] == "HomoSapiens") & 
#                                  (df["gene"] == "TRB") & 
                                 (df["cdr3fix.good"]) & 
                                 ~(df["reference.id"].str.contains("10x"))]

df_human_no10x_size = df_human_no10x.loc[ (df_human_no10x["antigen.epitope"].str.len() >= 8) &
                                                 (df_human_no10x["antigen.epitope"].str.len() <= 13) &
                                                 (df_human_no10x["cdr3"].str.len() >= 10) &
                                                 (df_human_no10x["cdr3"].str.len() <= 20)]

df_human_no10x_size = df_human_no10x_size.drop_duplicates(columns)

print(f"Restricting on size reduced the number of unique pairs from {df_human_no10x.drop_duplicates(columns).shape[0]} to {df_human_no10x_size.shape[0]}.")
print(f"In other words, {df_human_no10x.drop_duplicates(columns).shape[0] - df_human_no10x_size.shape[0]} entries (or {(df_human_no10x.drop_duplicates(columns).shape[0] - df_human_no10x_size.shape[0]) / df_human_no10x.drop_duplicates(columns).shape[0]} %) were dropped.")
# Out:
# Restricting on size reduced the number of unique pairs from 22198 to 20836.
# In other words, 1362 entries (or 0.06135687899810794 %) were dropped.

# %%
df_human_trb_no10x = df.loc[(df["species"] == "HomoSapiens") & 
                                 (df["gene"] == "TRB") & 
                                 (df["cdr3fix.good"]) & 
                                 ~(df["reference.id"].str.contains("10x"))]

df_human_trb_no10x_size = df_human_trb_no10x.loc[ (df_human_trb_no10x["antigen.epitope"].str.len() >= 8) &
                                                 (df_human_trb_no10x["antigen.epitope"].str.len() <= 13) &
                                                 (df_human_trb_no10x["cdr3"].str.len() >= 10) &
                                                 (df_human_trb_no10x["cdr3"].str.len() <= 20)]

df_human_trb_no10x_size = df_human_trb_no10x_size.drop_duplicates(columns)

print(f"Restricting on size reduced the number of unique pairs from {df_human_trb_no10x.drop_duplicates(columns).shape[0]} to {df_human_trb_no10x_size.shape[0]}.")
print(f"In other words, {df_human_trb_no10x.drop_duplicates(columns).shape[0] - df_human_trb_no10x_size.shape[0]} entries (or {(df_human_trb_no10x.drop_duplicates(columns).shape[0] - df_human_trb_no10x_size.shape[0]) / df_human_trb_no10x.drop_duplicates(columns).shape[0]} %) were dropped.")
# Out:
# Restricting on size reduced the number of unique pairs from 15642 to 14830.
# In other words, 812 entries (or 0.051911520265950646 %) were dropped.

# %%
df_human_trb_no10x = df.loc[(df["species"] == "HomoSapiens") & 
                                 (df["gene"] == "TRB") & 
                                 (df["cdr3fix.good"]) & 
                                 ~(df["reference.id"].str.contains("10x"))]

# does this matter? Using df indices rather than new df_human_trb_no10x?
df_human_trb_no10x_size = df_human_trb_no10x.loc[ (df["antigen.epitope"].str.len() >= 8) &
                                                 (df["antigen.epitope"].str.len() <= 13) &
                                                 (df["cdr3"].str.len() >= 10) &
                                                 (df["cdr3"].str.len() <= 20)]

df_human_trb_no10x_size = df_human_trb_no10x_size.drop_duplicates(columns)

print(f"Restricting on size reduced the number of unique pairs from {df_human_trb_no10x.drop_duplicates(columns).shape[0]} to {df_human_trb_no10x_size.shape[0]}.")
print(f"In other words, {df_human_trb_no10x.drop_duplicates(columns).shape[0] - df_human_trb_no10x_size.shape[0]} entries (or {(df_human_trb_no10x.drop_duplicates(columns).shape[0] - df_human_trb_no10x_size.shape[0]) / df_human_trb_no10x.drop_duplicates(columns).shape[0]} %) were dropped.")
# Out:
# Restricting on size reduced the number of unique pairs from 15642 to 14830.
# In other words, 812 entries (or 0.051911520265950646 %) were dropped.

# %% [markdown]
# ## Comparison to Dean et al. negative reference TCR set

# %%
negative_ref_path = PROJECT_ROOT / "data/raw/CDR3_control_sequences.tsv"
df_negative = pd.read_csv(negative_ref_path, sep="\t")
df_negative["cdr3.len"] = df_negative["CDR3_beta"].str.len()

print(df_negative.shape)
print(df_negative.drop_duplicates(subset="CDR3_beta").shape)
# Out:
# (500000, 4)
# (487437, 4)

# %%
df_negative = df_negative.loc[(df_negative["cdr3.len"] >= 10) &
                              (df_negative["cdr3.len"] <= 20)]
print(df_negative.shape)
print(df_negative.drop_duplicates(subset="CDR3_beta").shape)
# Out:
# (497459, 4)
# (484914, 4)

# %%
len(set(df_negative["CDR3_beta"]).intersection(df_human_no10x_size["cdr3"]))
# Out:
# 1184

# %% [markdown]
# ## TRB only

# %% [markdown]
# ### Epitope and CDR3 length distribution

# %%
df_human_trb_no10x_size.shape
# Out:
# (14830, 57)

# %% [markdown]
# #### No grouping

# %%
fig, axs = plt.subplots(2, dpi=200)#, figsize = (15,10))
fig.subplots_adjust(hspace=.4)

# cdr3 length
sns.countplot(x="cdr3.len", data=df_human_no10x_size,
              alpha=.8,
#               palette=sns.color_palette("BuGn_r", 18),
              color=sns.color_palette("BuGn_r")[2],
              ax=axs[0])
# epitope length
sns.countplot(x="antigen.epitope.len", data=df_human_no10x_size,
#                    order=df_human_trb_10x["antigen.epitope.len"].value_counts().iloc[:5].index,
              alpha=.8,
#               color=sns.color_palette("Set1")[1],
#               palette=sns.color_palette("BuGn_r", 10),
              color=sns.color_palette("BuGn_r")[2],
              ax=axs[1])

# axs[1].set_title('Epitope length distribution')#, fontsize = 14)
# axs[0].set_title('CDR3 length distribution')#, fontsize = 14)
axs[0].set_title('Sequence length distribution')
axs[0].set_ylabel('Count')
axs[1].set_ylabel('Count')
axs[0].set_xlabel('CDR3 length')
axs[1].set_xlabel('Epitope length')
# plt.legend(title='MHC class', loc='upper right')

# plt.savefig(PROJECT_ROOT / "reports/figures/length-distribution.png")
# plt.savefig(PROJECT_ROOT / "reports/figures/length-distribution.pdf")
# bbox_inches='tight'
# Out:
# Text(0.5, 0, 'Epitope length')

# %% [markdown]
# #### Per MHC:

# %%
fig, axs = plt.subplots(2, dpi=200, figsize=(8,8))#, figsize = (15,10))
fig.subplots_adjust(hspace=.4)

# cdr3 length
sns.countplot(x="cdr3.len", hue="mhc.class", data=df_human_trb_no10x_size,
              alpha=.8,
              palette=sns.color_palette("BuGn_r", 2),
#               color=sns.color_palette("BuGn_r")[2],
              ax=axs[0])
# epitope length
sns.countplot(x="antigen.epitope.len", hue="mhc.class", data=df_human_trb_no10x_size,
#                    order=df_human_trb_10x["antigen.epitope.len"].value_counts().iloc[:5].index,
              alpha=.8,
#               color=sns.color_palette("Set1")[1],
              palette=sns.color_palette("BuGn_r", 2),
#               color=sns.color_palette("BuGn_r")[2],
              ax=axs[1])

# axs[1].set_title('Epitope length distribution', fontsize = 14)
# axs[0].set_title('CDR3 length distribution', fontsize = 14)
axs[0].set_title('Sequence length distribution for TRB chains')
axs[0].set_ylabel('Log count')
axs[1].set_ylabel('Log count')
axs[0].set_xlabel('CDR3 length')
axs[1].set_xlabel('Epitope length')

axs[0].set(yscale="log")
axs[1].set(yscale="log")

ax.set_title('CDR3 length distribution per MHC class in human TRB entries (non-spurious, no 10x data)')
ax.set_ylabel('Count')
ax.set_xlabel('CDR3 length')
axs[0].legend(title='MHC class', loc='upper right')
axs[1].legend(title='MHC class', loc='upper right')


# plt.legend(title='MHC class', loc='upper right')

# %% [markdown]
# The length distribution of the epitopes of MHCII differs drastically from the non-filtered data.

# %%
df_human_trb.groupby(["mhc.class", "antigen.epitope.len"]).size()
# Out:
# mhc.class  antigen.epitope.len
# MHCI       8                       1209
#            9                      25317
#            10                      4551
#            11                       313
#            12                       104
#            13                        13
#            15                         6
# MHCII      11                         1
#            12                         1
#            13                       525
#            14                       187
#            15                        36
#            16                       144
#            20                       367
# dtype: int64

# %%
df_human_trb_no10x_size.groupby(["mhc.class", "antigen.epitope.len"]).size()
# Out:
# mhc.class  antigen.epitope.len
# MHCI       8                        551
#            9                      10853
#            10                      2473
#            11                       312
#            12                       104
#            13                        13
# MHCII      11                         1
#            12                         1
#            13                       522
# dtype: int64

# %% [markdown]
# ## Can MHCI and MHCII share epitopes?

# %%
set(df.loc[df["mhc.class"] == "MHCI", "antigen.epitope"].unique()).intersection(df.loc[df["mhc.class"] == "MHCII", "antigen.epitope"].unique())
# Out:
# set()

# %% [markdown]
# Technically there is an overlap in the length distribution, but no epitopes are shared in the VDJdb dataset.

# %% [markdown]
# ## TRB and TRA

# %% [markdown]
# ### Epitope counts

# %%
len(df["antigen.epitope"].unique())
# Out:
# 222

# %%
len(df_human_no10x["antigen.epitope"].unique())
# Out:
# 163

# %%
len(df_human_no10x_size["antigen.epitope"].unique())
# Out:
# 141

# %%
df_human_no10x_size.groupby("antigen.epitope").size().sort_values(ascending=False)
# Out:
# antigen.epitope
# NLVPMVATV        6452
# GILGFVFTL        5289
# ELAGIGILTV       1002
# GLCTLVAML         991
# LLWNGPMAV         649
#                  ...
# DEEDAIAAY           1
# MLWGYLQYV           1
# PKYVKQNTLKLAR       1
# ELAGIGALTV          1
# LLFGYAVYV           1
# Length: 141, dtype: int64

# %%
df_human_no10x_size.groupby("antigen.epitope").size().sort_values(ascending=False).plot.hist()

# %%
ax = sns.distplot(df_human_no10x_size.groupby("antigen.epitope").size().sort_values(ascending=False), kde=False)#, bins=500)
#                    order=df_human_no10x_size["antigen.epitope"].value_counts().iloc[:20].index, 
#                    data=df_human_no10x_size, 
#                    edgecolor=".2", linewidth=.5, 
#                    alpha=.8, color=sns.color_palette("Set1")[0])

# ax.set(yscale="log")

# %%
ax = sns.countplot(x=df_human_no10x_size.groupby("antigen.epitope").size().sort_values(ascending=False),
#                    order=df_human_no10x_size["antigen.epitope"].value_counts().iloc[:20].index, 
#                    data=df_human_no10x_size, 
#                    edgecolor=".2", linewidth=.5, 
                   alpha=.8, color=sns.color_palette("Set1")[0])

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=45, ha='right')
ax = sns.countplot(x="antigen.epitope",
                   order=df_human_no10x_size["antigen.epitope"].value_counts().index, 
                   data=df_human_no10x_size, 
#                    edgecolor=".2", linewidth=.5, 
                   alpha=.8, color=sns.color_palette("Set1")[0])

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=45, ha='right')
ax = sns.countplot(x="antigen.epitope",
                   order=df_human_no10x_size["antigen.epitope"].value_counts().iloc[:20].index, 
                   data=df_human_no10x_size, 
#                    edgecolor=".2", linewidth=.5, 
                   alpha=.8, color=sns.color_palette("Set1")[0])

# %% [markdown]
# #### Combined figure - histogram of abundances and epitope counts

# %%
from matplotlib.gridspec import GridSpec

# fig, axs = plt.subplots(nrows=3, ncols=2, squeeze=False, dpi=200, figsize=(10,8))#, figsize = (15,10))
# fig.subplots_adjust(hspace=.3, wspace=.3)

fig = plt.figure(constrained_layout=True, dpi=200, figsize=(10,5))
gs = GridSpec(1, 2, figure=fig)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

# epitope distribution
sns.countplot(x="antigen.epitope",
                   order=df_human_no10x_size["antigen.epitope"].value_counts().iloc[:30].index, 
                   data=df_human_no10x_size, 
#                    edgecolor=".2", linewidth=.5, 
              alpha=.8,color="#23373b",
#               color=["#23373b"],
#               color=sns.color_palette("Set1")[0],
             ax=ax1)
ax1.tick_params(labelrotation=90)

# #23373b

ax1.set_title('Epitope abundance (30 out of 154)')
ax1.set_xlabel('Epitope')
ax1.set_ylabel("Cout")


# cdr3 length - TRB
# sns.countplot(x="cdr3.len", hue="mhc.class",
#               data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRB"],
#               alpha=.8, palette=sns.color_palette("BuGn_r", 3),
#               ax=ax1)



sns.distplot(df_human_no10x_size.groupby("antigen.epitope").size().sort_values(ascending=False), 
             kde=False, 
             color="#23373b",
             ax=ax2)#, bins=500)
#                    order=df_human_no10x_size["antigen.epitope"].value_counts().iloc[:20].index, 
#                    data=df_human_no10x_size, 
#                    edgecolor=".2", linewidth=.5, 
#                    alpha=.8, color=sns.color_palette("Set1")[0])
# ax.set(yscale="log")

ax2.set_title('Number of epitopes with a specific abundance')
ax2.set_xlabel('Epitope frequency')
ax2.set_ylabel('Number of epitopes')
ax2.set(yscale="log")
ax2.legend(title="154 unique epitopes", loc='upper right')


# [i.set_ylabel("Log count") for i in [ax1,ax2,ax3,ax4] ]
# [i.set(yscale="log") for i in [ax1,ax2,ax3,ax4]]
# [i.legend(title='MHC class', loc='upper right') for i in [ax1,ax2,ax3,ax4] ]


# # plt.xticks(rotation=90)#, ha='right')

# ax5.set_title('Epitope distribution per TCR chain')
# ax5.set_ylabel('Count')
# ax5.set_xlabel('Epitope')
# ax5.legend(title='TCR chain', loc='upper right')

plt.savefig(PROJECT_ROOT / "reports/figures/epitope-distribution.pdf", bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# ## MHC distribution

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=45)
ax = sns.countplot(x="mhc.a", order=df_human_no10x_size["mhc.a"].value_counts().iloc[:30].index, data=df_human_no10x_size, edgecolor=".2", linewidth=.5, alpha=.75)

# %%
# fig, axs = plt.subplots(2, figsize = (15,10))
# axs[0].tick_params(axis='x', labelrotation=30)
# plt.xticks(ha='right')
# axs[1].tick_params(axis='x', labelrotation=30)
# plt.xticks(ha='right')
# sns.countplot(x="mhc.a", order=df_human_trb_10x["mhc.a"].value_counts().iloc[:30].index, 
#                    data=df_human_trb_10x, edgecolor=".2", linewidth=.5, alpha=.75,
#                   ax=axs[0])
# sns.countplot(x="mhc.a", order=df_human_trb_10x["mhc.a"].value_counts().iloc[-30:].index, 
#                    data=df_human_trb_10x, edgecolor=".2", linewidth=.5, alpha=.75,
#                   ax=axs[1])

# %% [markdown]
# ## Combined figure

# %% [markdown]
# ### Simple figure

# %%
len(df_human_no10x_size["antigen.epitope"].unique())
# Out:
# 141

# %%
len(df_human_trb_no10x_size["antigen.epitope"].unique())
# Out:
# 139

# %%
fig, axs = plt.subplots(3, dpi=200, figsize = (10,8))
fig.subplots_adjust(hspace=.5)

# cdr3 length
sns.countplot(x="cdr3.len", hue="gene", data=df_human_no10x_size.sort_values(by="gene"),
              alpha=.8,palette=sns.color_palette("BuGn_r", 3),
#               color=sns.color_palette("BuGn_r")[2],
              ax=axs[0])
# epitope length
sns.countplot(x="antigen.epitope.len", hue="gene", data=df_human_no10x_size.sort_values(by="gene"),
              alpha=.8,palette=sns.color_palette("BuGn_r", 3),
#               color=sns.color_palette("BuGn_r")[2],
              ax=axs[1])


axs[0].set_title('CDR3 length distribution')
axs[1].set_title('Epitope length distribution')
axs[0].set_ylabel('Interaction count')
axs[1].set_ylabel('Interaction count')
axs[0].set_xlabel('CDR3 length')
axs[1].set_xlabel('Epitope length')
axs[0].legend(title='TCR chain', loc='upper right')
axs[1].legend(title='TCR chain', loc='upper right')

# epitope distribution
sns.countplot(x="antigen.epitope", hue="gene",
              order=df_human_no10x_size.sort_values(by="gene")["antigen.epitope"].value_counts().iloc[:30].index, 
              data=df_human_no10x_size, 
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
#               color=sns.color_palette("BuGn_r")[1],
              ax=axs[2])

plt.xticks(rotation=90)#, ha='right')
axs[2].set_title('Epitope distribution (top 30 most abundant out of 140)')
axs[2].set_ylabel('Interaction count')
axs[2].set_xlabel('Epitope')
axs[2].legend(title='TCR chain', loc='upper right')

import string
for n, ax in enumerate(axs):
    ax.text(-0.1, 1.1, string.ascii_uppercase[n], transform=ax.transAxes, 
            size=20, weight='bold')
    
plt.setp(axs[2].get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

plt.savefig(PROJECT_ROOT / "reports/figures/vdjdb-distribution-simple.png", bbox_inches="tight")
plt.savefig(PROJECT_ROOT / "reports/figures/vdjdb-distribution-simple.pdf", bbox_inches="tight")
# Out:
# 'SourceSansPro-Bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# ### Length only

# %%
df_human_no10x_size.groupby("gene").size()
# Out:
# gene
# TRA     6006
# TRB    14830
# dtype: int64

# %%
from matplotlib.gridspec import GridSpec

fig, axs = plt.subplots(nrows=2, ncols=2, squeeze=False, dpi=200, figsize=(10,8))#, figsize = (15,10))
fig.subplots_adjust(hspace=.3, wspace=.3)


# cdr3 length - TRB
sns.countplot(x="cdr3.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRB"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 2),
              ax=axs[0,0])
# epitope length - TRB
sns.countplot(x="antigen.epitope.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRB"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 2),
              ax=axs[1,0])
# cdr3 length - TRA
sns.countplot(x="cdr3.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRA"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 2),
              ax=axs[0,1])
# epitope length - TRA
sns.countplot(x="antigen.epitope.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRA"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 2),
              ax=axs[1,1])

[axs[i,j].set_ylabel("Log count") for i in range(2) for j in range(2) ]
[axs[i,j].set(yscale="log") for i in range(2) for j in range(2) ]
[axs[i,j].legend(title='MHC class', loc='upper right') for i in range(2) for j in range(2) ]

axs[1,0].set_title('Epitope length distribution for TRB genes')
axs[1,1].set_title('Epitope length distribution for TRA genes')
axs[1,0].set_xlabel('Epitope length')
axs[1,1].set_xlabel('Epitope length')

axs[0,1].set_title('CDR3 length distribution for TRB genes')
axs[0,0].set_title('CDR3 length distribution for TRA genes')
axs[0,1].set_xlabel('CDR3 length')
axs[0,0].set_xlabel('CDR3 length')
# Out:
# Text(0.5, 0, 'CDR3 length')

# %% [markdown]
# ### Chain split and per-figure MHC

# %%
df_human_no10x_size.groupby("mhc.class").size()
# Out:
# mhc.class
# MHCI     20061
# MHCII      775
# dtype: int64

# %%
df_human_no10x_size.groupby("gene").size()
# Out:
# gene
# TRA     6006
# TRB    14830
# dtype: int64

# %%
from matplotlib.gridspec import GridSpec

# fig, axs = plt.subplots(nrows=3, ncols=2, squeeze=False, dpi=200, figsize=(10,8))#, figsize = (15,10))
# fig.subplots_adjust(hspace=.3, wspace=.3)

fig = plt.figure(constrained_layout=True, dpi=200, figsize=(12,10))
gs = GridSpec(3, 2, figure=fig)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[2, :])


# cdr3 length - TRB
sns.countplot(x="cdr3.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRB"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax1)
# epitope length - TRB
sns.countplot(x="antigen.epitope.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRB"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax2)
# cdr3 length - TRA
sns.countplot(x="cdr3.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRA"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax3)
# epitope length - TRA
sns.countplot(x="antigen.epitope.len", hue="mhc.class",
              data=df_human_no10x_size.loc[df_human_no10x_size["gene"]=="TRA"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax4)

[i.set_ylabel("Log count") for i in [ax1,ax2,ax3,ax4] ]
[i.set(yscale="log") for i in [ax1,ax2,ax3,ax4]]
[i.legend(title='MHC class', loc='upper right') for i in [ax1,ax2,ax3,ax4] ]

ax2.set_title('Epitope length distribution for TRB genes')
ax4.set_title('Epitope length distribution for TRA genes')
ax2.set_xlabel('Epitope length')
ax4.set_xlabel('Epitope length')

ax1.set_title('CDR3 length distribution for TRB genes')
ax3.set_title('CDR3 length distribution for TRA genes')
ax1.set_xlabel('CDR3 length')
ax3.set_xlabel('CDR3 length')

# epitope distribution
sns.countplot(x="antigen.epitope", hue="gene",
              order=df_human_no10x_size["antigen.epitope"].value_counts().iloc[:30].index, 
              data=df_human_no10x_size, 
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
#               color=sns.color_palette("BuGn_r")[1],
              ax=ax5)

plt.xticks(rotation=90)#, ha='right')

ax5.set_title('Epitope distribution per TCR chain')
ax5.set_ylabel('Count')
ax5.set_xlabel('Epitope')
ax5.legend(title='TCR chain', loc='upper right')

import string
for n, ax in enumerate(fig.axes):
    ax.text(-0.1, 1.1, string.ascii_uppercase[n], transform=ax.transAxes, 
            size=20, weight='bold')

plt.savefig(PROJECT_ROOT / "reports/figures/vdjdb-distribution-chainsplit.png")
plt.savefig(PROJECT_ROOT / "reports/figures/vdjdb-distribution-chainsplit.pdf", bbox_inches="tight")
# bbox_inches='tight'
# Out:
# 'SourceSansPro-Bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# ### MHC split and per-figure chains + more details

# %%
from matplotlib.gridspec import GridSpec

# fig, axs = plt.subplots(nrows=3, ncols=2, squeeze=False, dpi=200, figsize=(10,8))#, figsize = (15,10))
# fig.subplots_adjust(hspace=.3, wspace=.3)

fig = plt.figure(constrained_layout=True, dpi=200, figsize=(12,16))
gs = GridSpec(5, 2, figure=fig)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[2, :])
ax6 = fig.add_subplot(gs[3, :])
ax7 = fig.add_subplot(gs[4, :])


# cdr3 length - TRB
sns.countplot(x="cdr3.len", hue="gene",
              data=df_human_no10x_size.loc[df_human_no10x_size["mhc.class"]=="MHCI"].sort_values(by="gene"),
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax1)
# epitope length - TRB
sns.countplot(x="antigen.epitope.len", hue="gene",
              data=df_human_no10x_size.loc[df_human_no10x_size["mhc.class"]=="MHCI"].sort_values(by="gene"),
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax2)
# cdr3 length - TRA
sns.countplot(x="cdr3.len", hue="gene",
              data=df_human_no10x_size.loc[df_human_no10x_size["mhc.class"]=="MHCII"].sort_values(by="gene"),
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax3)
# epitope length - TRA
sns.countplot(x="antigen.epitope.len", hue="gene",
              data=df_human_no10x_size.loc[df_human_no10x_size["mhc.class"]=="MHCII"].sort_values(by="gene"),
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax4)

[i.set_ylabel("Interaction count") for i in [ax1,ax2,ax3,ax4] ]
# [i.set(yscale="log") for i in [ax1,ax2,ax3,ax4]]
[i.legend(title='TCR chain', loc='upper left') for i in [ax1,ax2,ax3,ax4] ]

ax2.set_title('Epitope length distribution for MHCI')
ax4.set_title('Epitope length distribution for MHCII')
ax2.set_xlabel('Epitope length')
ax4.set_xlabel('Epitope length')

ax1.set_title('CDR3 length distribution for MHCI')
ax3.set_title('CDR3 length distribution for MHCII')
ax1.set_xlabel('CDR3 length')
ax3.set_xlabel('CDR3 length')

# epitope distribution
sns.countplot(x="antigen.epitope", hue="gene",
              order=df_human_no10x_size["antigen.epitope"].value_counts().iloc[:30].index, 
              data=df_human_no10x_size.sort_values(by="gene"), 
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
#               color=sns.color_palette("BuGn_r")[1],
              ax=ax5)

ax5.tick_params(labelrotation=90)
ax5.set_title('Epitope distribution (top 30 most abundant out of 140)')
ax5.set_ylabel('Interaction count')
ax5.set_xlabel('Epitope')
ax5.legend(title='TCR chain', loc='upper right')

# MHC distribution A
sns.countplot(x="mhc.a",hue="gene",
                order=df_human_no10x_size["mhc.a"].value_counts().index, 
                data=df_human_no10x_size.sort_values(by="gene"), 
                palette=sns.color_palette("BuGn_r", 3),
                alpha=.8,
             ax=ax6)

ax6.tick_params(labelrotation=90)
ax6.set_ylabel('Interaction count')
ax6.set_xlabel('First MHC chain')
ax6.set_title('First MHC chain allele distribution')
ax6.legend(title='TCR chain', loc='upper right')


# MHC distribution B
sns.countplot(x="mhc.b",hue="gene",
                order=df_human_no10x_size["mhc.b"].value_counts().index, 
                data=df_human_no10x_size.sort_values(by="gene"), 
                palette=sns.color_palette("BuGn_r", 3),
                alpha=.8,
             ax=ax7)

ax7.tick_params(labelrotation=90)
ax7.set_ylabel('Log interaction count')
ax7.set_xlabel('Second MHC chain')
ax7.set_title('Second MHC chain allele distribution')
ax7.legend(title='TCR chain', loc='upper right')
ax7.set(yscale="log")

import string
for n, ax in enumerate(fig.axes):
    ax.text(-0.1, 1.1, string.ascii_uppercase[n], transform=ax.transAxes, 
            size=20, weight='bold')

[plt.setp(i.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor") for i in [ax5,ax6,ax7]]

plt.savefig(PROJECT_ROOT / "reports/figures/vdjdb-distribution-detailed.png")
plt.savefig(PROJECT_ROOT / "reports/figures/vdjdb-distribution-detailed.pdf", bbox_inches="tight")
# Out:
# 'SourceSansPro-Bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'SourceSansPro-Regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# ## Dean reference set TCR distribution

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=45, ha='right')
ax = sns.countplot(x="CDR3_beta",
                   order=df_negative["CDR3_beta"].value_counts().iloc[:30].index, 
                   data=df_negative, 
#                    edgecolor=".2", linewidth=.5, 
                   alpha=.8, color=sns.color_palette("Set1")[0])

# %%
plt.figure()#figsize=(15,10))
plt.xticks(rotation=45, ha='right')
ax = sns.countplot(x="CDR3_beta",
                   order=df_negative["CDR3_beta"].value_counts().iloc[:-30:-1].index, 
                   data=df_negative, 
#                    edgecolor=".2", linewidth=.5, 
                   alpha=.8, color=sns.color_palette("Set1")[0])

# %%
sns.distplot(df_negative.groupby("CDR3_beta").size().sort_values(ascending=False), 
             kde=False, 
             color="#23373b")

# %%
df_negative.groupby("CDR3_beta").size().sort_values(ascending=False).value_counts()
# Out:
# 1    473965
# 2      9613
# 3      1115
# 4       184
# 5        35
# 6         2
# dtype: int64

# %%
df_negative.shape
# Out:
# (497459, 4)

# %%
df_negative.drop_duplicates().shape
# Out:
# (497459, 4)

# %%
df_negative["CDR3_beta"].shape
# Out:
# (497459,)

# %%
df_negative["CDR3_beta"].drop_duplicates().shape
# Out:
# (484914,)

# %%
df_negative.drop_duplicates(subset="CDR3_beta").shape
# Out:
# (484914, 4)

# %% [markdown]
# # TODO
#
# Restrict on MHCI class, because our length restriction basically cuts out the majority of MHCII.

# %%
from matplotlib.gridspec import GridSpec

# fig, axs = plt.subplots(nrows=3, ncols=2, squeeze=False, dpi=200, figsize=(10,8))#, figsize = (15,10))
# fig.subplots_adjust(hspace=.3, wspace=.3)

fig = plt.figure(constrained_layout=True, dpi=200, figsize=(12,10))
gs = GridSpec(3, 2, figure=fig)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[2, :])


# cdr3 length - TRB
sns.countplot(x="cdr3.len", hue="mhc.class",
              data=df_human.loc[df_human["gene"]=="TRB"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax1)
# epitope length - TRB
sns.countplot(x="antigen.epitope.len", hue="mhc.class",
              data=df_human.loc[df_human["gene"]=="TRB"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax2)
# cdr3 length - TRA
sns.countplot(x="cdr3.len", hue="mhc.class",
              data=df_human.loc[df_human["gene"]=="TRA"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax3)
# epitope length - TRA
sns.countplot(x="antigen.epitope.len", hue="mhc.class",
              data=df_human.loc[df_human["gene"]=="TRA"],
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
              ax=ax4)

[i.set_ylabel("Log count") for i in [ax1,ax2,ax3,ax4] ]
[i.set(yscale="log") for i in [ax1,ax2,ax3,ax4]]
[i.legend(title='MHC class', loc='upper right') for i in [ax1,ax2,ax3,ax4] ]

ax2.set_title('Epitope length distribution for TRB genes')
ax4.set_title('Epitope length distribution for TRA genes')
ax2.set_xlabel('Epitope length')
ax4.set_xlabel('Epitope length')

ax1.set_title('CDR3 length distribution for TRB genes')
ax3.set_title('CDR3 length distribution for TRA genes')
ax1.set_xlabel('CDR3 length')
ax3.set_xlabel('CDR3 length')

# epitope distribution
sns.countplot(x="antigen.epitope", hue="gene",
              order=df_human["antigen.epitope"].value_counts().iloc[:30].index, 
              data=df_human, 
              alpha=.8, palette=sns.color_palette("BuGn_r", 3),
#               color=sns.color_palette("BuGn_r")[1],
              ax=ax5)

plt.xticks(rotation=90)#, ha='right')

ax5.set_title('Epitope distribution per TCR chain')
ax5.set_ylabel('Count')
ax5.set_xlabel('Epitope')
ax5.legend(title='TCR chain', loc='upper right')

# %%
df_human
# Out:
#        complex.id gene              cdr3       v.segm      j.segm  \
# 0               0  TRB    CSVWGTGKTYEQYF  TRBV29-1*01  TRBJ2-7*01
# 1               0  TRB    CSVWGEGRSYEQYF  TRBV29-1*01  TRBJ2-7*01
# 2               0  TRB  CSATILAGVPYGEQYF  TRBV20-1*01  TRBJ2-7*01
# 4               0  TRB    CSASEGTSSYEQYF  TRBV20-1*01  TRBJ2-7*01
# 5               0  TRB   CASSFDREVTGELFF   TRBV7-3*01  TRBJ2-2*01
# ...           ...  ...               ...          ...         ...
# 76158           0  TRB     CASVTGSTDTQYF     TRBV2*01  TRBJ2-3*01
# 76159           0  TRB     CASSDGTAYEQYF     TRBV2*01  TRBJ2-7*01
# 76160           0  TRB     CASSLARNQPQHF   TRBV4-1*01  TRBJ1-5*01
# 76161           0  TRB    CASGGADMKTEAFF    TRBV19*01  TRBJ1-1*01
# 76163           0  TRB    CASSPGGGKETQYF   TRBV7-6*01  TRBJ2-5*01
#
#            species     mhc.a mhc.b mhc.class antigen.epitope  ...  \
# 0      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 1      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 2      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 4      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 5      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# ...            ...       ...   ...       ...             ...  ...
# 76158  HomoSapiens  HLA-B*18   B2M      MHCI       ELKRKMIYM  ...
# 76159  HomoSapiens  HLA-B*18   B2M      MHCI       ELKRKMIYM  ...
# 76160  HomoSapiens  HLA-B*18   B2M      MHCI       CVETMCNEY  ...
# 76161  HomoSapiens  HLA-B*18   B2M      MHCI       CVETMCNEY  ...
# 76163  HomoSapiens  HLA-B*18   B2M      MHCI       DEEDAIAAY  ...
#
#        cdr3fix.vId cdr3fix.oldVEnd cdr3fix.oldVFixType  cdr3fix.oldVId  \
# 0      TRBV29-1*01             NaN                 NaN             NaN
# 1      TRBV29-1*01             NaN                 NaN             NaN
# 2      TRBV20-1*01             NaN                 NaN             NaN
# 4      TRBV20-1*01             NaN                 NaN             NaN
# 5       TRBV7-3*01             NaN                 NaN             NaN
# ...            ...             ...                 ...             ...
# 76158     TRBV2*01             NaN                 NaN             NaN
# 76159     TRBV2*01             NaN                 NaN             NaN
# 76160   TRBV4-1*01             NaN                 NaN             NaN
# 76161    TRBV19*01             NaN                 NaN             NaN
# 76163   TRBV7-6*01             NaN                 NaN             NaN
#
#       cdr3fix.oldJFixType cdr3fix.oldJStart cdr3fix.oldJId  \
# 0                     NaN               NaN            NaN
# 1                     NaN               NaN            NaN
# 2                     NaN               NaN            NaN
# 4                     NaN               NaN            NaN
# 5                     NaN               NaN            NaN
# ...                   ...               ...            ...
# 76158                 NaN               NaN            NaN
# 76159                 NaN               NaN            NaN
# 76160                 NaN               NaN            NaN
# 76161                 NaN               NaN            NaN
# 76163                 NaN               NaN            NaN
#
#                           merged cdr3.len antigen.epitope.len
# 0        CSVWGTGKTYEQYF-FLKEKGGL       14                   8
# 1        CSVWGEGRSYEQYF-FLKEKGGL       14                   8
# 2      CSATILAGVPYGEQYF-FLKEKGGL       16                   8
# 4        CSASEGTSSYEQYF-FLKEKGGL       14                   8
# 5       CASSFDREVTGELFF-FLKEKGGL       15                   8
# ...                          ...      ...                 ...
# 76158    CASVTGSTDTQYF-ELKRKMIYM       13                   9
# 76159    CASSDGTAYEQYF-ELKRKMIYM       13                   9
# 76160    CASSLARNQPQHF-CVETMCNEY       13                   9
# 76161   CASGGADMKTEAFF-CVETMCNEY       14                   9
# 76163   CASSPGGGKETQYF-DEEDAIAAY       14                   9
#
# [55134 rows x 57 columns]

# %%
len(df_human["antigen.epitope"].unique())
# Out:
# 186

# %%
len(df_human_no10x_size["antigen.epitope"].unique())
# Out:
# 141

# %%
df_human_no10x = df.loc[(df["species"] == "HomoSapiens") & 
#                                  (df["gene"] == "TRB") & 
                                 (df["cdr3fix.good"]) & 
                                 ~(df["reference.id"].str.contains("10x"))]

df_human_no10x_size = df_human_no10x.loc[ (df_human_no10x["antigen.epitope"].str.len() >= 8) &
                                                 (df_human_no10x["antigen.epitope"].str.len() <= 13) &
                                                 (df_human_no10x["cdr3"].str.len() >= 10) &
                                                 (df_human_no10x["cdr3"].str.len() <= 20)]

df_human_no10_size = df_human_no10x.loc[(df_human_no10x["gene"] == "TRB")]

df_human_no10x_size = df_human_no10x_size.drop_duplicates(columns)

df_human_no10x_size.shape
# Out:
# (20836, 57)

# %%
import json

import pandas as pd
from pandas.io.json import json_normalize
from pathlib import Path

from src.config import PROJECT_ROOT
from src.preprocessing import preprocess_vdjdb
# import dataset again to start fresh
vdjdb_normal_path = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt"
df = pd.read_csv(vdjdb_normal_path, sep="\t")

# expand the json/dict-like columns
df = (
    df.join(json_normalize(df["method"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("method."))
    .join(json_normalize(df["meta"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("meta."))
    .join(json_normalize(df["cdr3fix"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("cdr3fix."))
    .drop(["method", "meta", "cdr3fix"], axis=1)
)

columns = ["cdr3", "antigen.epitope"]

# create column based on cdr3 and epitope sequences
df["merged"] = df["cdr3"] + "-" + df["antigen.epitope"]

# create length columns for figures
df["cdr3.len"] = df["cdr3"].str.len()
df["antigen.epitope.len"] = df["antigen.epitope"].str.len()

# %%
df = df.loc[df["gene"] == "TRB"]
df.shape
# Out:
# (44920, 57)

# %%
df = df.loc[df["species"] == "HomoSapiens"]
df.shape
# Out:
# (39930, 57)

# %%
df = df.loc[df["cdr3fix.good"]]
df.shape
# Out:
# (39463, 57)

# %%
df = df.loc[
                ~(df["reference.id"].str.contains("|".join(["10xgenomics"])))
#             ~(df["reference.id"].str.contains("10xgenomics"))
        ]
df.shape
# Out:
# (19172, 57)

# %%
df = df.loc[
            (df["cdr3"].str.len() >= 10)
            & (df["cdr3"].str.len() <= 20)
            & (df["antigen.epitope"].str.len() >= 8)
            & (df["antigen.epitope"].str.len() <= 13)
        ]
df.shape
# Out:
# (18233, 57)

# %%
df.drop_duplicates(["cdr3","antigen.epitope"]).shape
# Out:
# (14830, 57)

# %%
from src.config import PROJECT_ROOT
import src.preprocessing.preprocess_vdjdb

# %%
df = src.preprocessing.preprocess_vdjdb.filter_vdjdb(
    input=PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt",
    tcr_chain="all",
    species="human",
    drop_spurious=True,
    mhc="all",
    hla="all",
#     specific_removal_epitope_reference="10xgenomics sdgfjhdsfgds",
    specific_removal_references=["10xgenomics"],
    keep_specific_references=None,
    length_restriction="10 20 8 13",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-21ad85c4b398> in <module>
#       9     specific_removal_references=["10xgenomics"],
#      10     keep_specific_references=None,
# ---> 11     length_restriction="10 20 8 13",
#      12 )
#
# /media/pieter/DATA/Wetenschap/Doctoraat/projects/deepTCR/deepTCR/src/preprocessing/preprocess_vdjdb.py in filter_vdjdb(input, tcr_chain, species, drop_spurious, mhc, hla, specific_removal_epitope_reference, specific_removal_references, keep_specific_references, length_restriction)
#     269     # Filter on sequence length
#     270     if length_restriction:
# --> 271         length_restriction = [int(n) for n in length_restriction]
#     272         assert_length_restrictions(length_restriction)
#     273         cdr3_min, cdr3_max, epitope_min, epitope_max = length_restriction
#
# /media/pieter/DATA/Wetenschap/Doctoraat/projects/deepTCR/deepTCR/src/preprocessing/preprocess_vdjdb.py in <listcomp>(.0)
#     269     # Filter on sequence length
#     270     if length_restriction:
# --> 271         length_restriction = [int(n) for n in length_restriction]
#     272         assert_length_restrictions(length_restriction)
#     273         cdr3_min, cdr3_max, epitope_min, epitope_max = length_restriction
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
df.shape

# %%
negative_ref_path = PROJECT_ROOT / "data/raw/CDR3_control_sequences.tsv"
df_negative = pd.read_csv(negative_ref_path, sep="\t")
df_negative["cdr3.len"] = df_negative["CDR3_beta"].str.len()

print(df_negative.shape)
print(df_negative.drop_duplicates(subset="CDR3_beta").shape)

# %% [markdown]
# # Difference between August 2019 and January 2020 release

# %%
# import dataset again to start fresh
vdjdb_normal_path = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2020-01-20/vdjdb.txt"
df = pd.read_csv(vdjdb_normal_path, sep="\t")

# expand the json/dict-like columns
df = (
    df.join(json_normalize(df["method"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("method."))
    .join(json_normalize(df["meta"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("meta."))
    .join(json_normalize(df["cdr3fix"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("cdr3fix."))
    .drop(["method", "meta", "cdr3fix"], axis=1)
)

columns = ["cdr3", "antigen.epitope"]

# create column based on cdr3 and epitope sequences
df["merged"] = df["cdr3"] + "-" + df["antigen.epitope"]

# create length columns for figures
df["cdr3.len"] = df["cdr3"].str.len()
df["antigen.epitope.len"] = df["antigen.epitope"].str.len()

df_jan = df

# %%
# import dataset again to start fresh
vdjdb_normal_path = PROJECT_ROOT / "data/raw/vdjdb/vdjdb-2019-08-08/vdjdb.txt"
df = pd.read_csv(vdjdb_normal_path, sep="\t")

# expand the json/dict-like columns
df = (
    df.join(json_normalize(df["method"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("method."))
    .join(json_normalize(df["meta"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("meta."))
    .join(json_normalize(df["cdr3fix"].apply(lambda x: json.loads(r'{}'.format(x)))).add_prefix("cdr3fix."))
    .drop(["method", "meta", "cdr3fix"], axis=1)
)

columns = ["cdr3", "antigen.epitope"]

# create column based on cdr3 and epitope sequences
df["merged"] = df["cdr3"] + "-" + df["antigen.epitope"]

# create length columns for figures
df["cdr3.len"] = df["cdr3"].str.len()
df["antigen.epitope.len"] = df["antigen.epitope"].str.len()

df_aug = df

# %% [markdown]
# This comparison will fail because there are duplicates within the dataframe: https://stackoverflow.com/questions/48647534/python-pandas-find-difference-between-two-data-frames

# %%
df_diff = pd.concat([df_aug,df_jan], sort=True).drop_duplicates(keep=False)

# %%
df_diff
# Out:
#       antigen.epitope  antigen.epitope.len antigen.gene antigen.species  \
# 135         GLCTLVAML                    9        BMLF1             EBV
# 137         GLCTLVAML                    9        BMLF1             EBV
# 138         GLCTLVAML                    9        BMLF1             EBV
# 154         GLCTLVAML                    9        BMLF1             EBV
# 156         GLCTLVAML                    9        BMLF1             EBV
# ...               ...                  ...          ...             ...
# 76147    DATYQRTRALVR                   12           NP      InfluenzaA
# 76148    DATYQRTRALVR                   12           NP      InfluenzaA
# 76149    DATYQRTRALVR                   12           NP      InfluenzaA
# 76150    DATYQRTRALVR                   12           NP      InfluenzaA
# 76151    DATYQRTRALVR                   12           NP      InfluenzaA
#
#                  cdr3  cdr3.len    cdr3fix.cdr3 cdr3fix.cdr3_old  \
# 135     CSARDRTGNGYTF        13   CSARDRTGNGYTF     CSARDRTGNGYT
# 137    CSVGTGGTNEKLFF        14  CSVGTGGTNEKLFF       CSVGTGGTNE
# 138    CSVGSGGTNEKLFF        14  CSVGSGGTNEKLFF       CSVGSGGTNE
# 154     CSARDGTGNGYTF        13   CSARDGTGNGYTF     CSARDGTGNGYT
# 156    CSARDRSLGNTIYF        14  CSARDRSLGNTIYF      CSARDRSLGNT
# ...               ...       ...             ...              ...
# 76147   CSARDRGREKLFF        13   CSARDRGREKLFF    CSARDRGREKLFF
# 76148     CAVNNNNDMRF        11     CAVNNNNDMRF      CAVNNNNDMRF
# 76149    CSGSQDPYEQYF        12    CSGSQDPYEQYF     CSGSQDPYEQYF
# 76150     CAVKFGQKLLF        11     CAVKFGQKLLF      CAVKFGQKLLF
# 76151    CTAEAGNTEAFF        12    CTAEAGNTEAFF     CTAEAGNTEAFF
#
#        cdr3fix.fixNeeded  cdr3fix.good  ...  mhc.b mhc.class   reference.id  \
# 135                 True          True  ...    B2M      MHCI  PMID:12504586
# 137                 True          True  ...    B2M      MHCI  PMID:12504586
# 138                 True          True  ...    B2M      MHCI  PMID:12504586
# 154                 True          True  ...    B2M      MHCI  PMID:12504586
# 156                 True          True  ...    B2M      MHCI  PMID:12504586
# ...                  ...           ...  ...    ...       ...            ...
# 76147              False          True  ...    B2M      MHCI  PMID:31811120
# 76148              False          True  ...    B2M      MHCI  PMID:31811120
# 76149              False          True  ...    B2M      MHCI  PMID:31811120
# 76150              False         False  ...    B2M      MHCI  PMID:31811120
# 76151              False          True  ...    B2M      MHCI  PMID:31811120
#
#            species       v.segm vdjdb.score  web.cdr3fix.nc  web.cdr3fix.unmp  \
# 135    HomoSapiens  TRBV20-1*01           2              no                no
# 137    HomoSapiens  TRBV29-1*01           3              no                no
# 138    HomoSapiens  TRBV29-1*01           3              no                no
# 154    HomoSapiens  TRBV20-1*01           1              no                no
# 156    HomoSapiens  TRBV20-1*01           1              no                no
# ...            ...          ...         ...             ...               ...
# 76147  HomoSapiens  TRBV20-1*01           0              no                no
# 76148  HomoSapiens  TRAV12-2*01           0              no                no
# 76149  HomoSapiens  TRBV20-1*01           0              no                no
# 76150  HomoSapiens   TRAV1-2*01           0              no               yes
# 76151  HomoSapiens   TRBV7-2*03           0              no                no
#
#       web.method web.method.seq
# 135      culture         sanger
# 137      culture         sanger
# 138      culture         sanger
# 154         sort         sanger
# 156         sort         sanger
# ...          ...            ...
# 76147       sort     singlecell
# 76148       sort     singlecell
# 76149       sort     singlecell
# 76150       sort     singlecell
# 76151       sort     singlecell
#
# [99269 rows x 57 columns]

# %% [markdown]
# The following approaches are not sensitive to duplicates:

# %%
df_aug[~df_aug.fillna('NULL').apply(tuple,1).isin(df_jan.fillna('NULL').apply(tuple,1))]
# Out:
#        complex.id gene              cdr3       v.segm      j.segm  \
# 15              0  TRA      CAVNSNTDKLIF  TRAV12-2*01   TRAJ34*01
# 55              0  TRB    CASSLNPSTDTQYF    TRBV27*01  TRBJ2-3*01
# 59              0  TRB   CASSATSGGADTQYF     TRBV9*01  TRBJ2-3*01
# 61              0  TRB     CSVPFAGADTQYF  TRBV29-1*01  TRBJ2-3*01
# 131             0  TRB   CASSSGQLTNTEAFF     TRBV9*01  TRBJ1-1*01
# ...           ...  ...               ...          ...         ...
# 75224       24500  TRB     CASSQALPYEQYF  TRBV12-4*01  TRBJ2-7*01
# 75225       24501  TRA       CAVCNFNKFYF    TRAV24*01   TRAJ21*01
# 75226       24501  TRB  CASSITLGTGGVEQYF    TRBV27*01  TRBJ2-7*01
# 75439           0  TRB  CASSQDGAGGLGEQFF   TRBV4-2*01  TRBJ2-1*01
# 75457           0  TRB     CASSIRSAYEQYF    TRBV19*01  TRBJ2-7*01
#
#            species        mhc.a mhc.b mhc.class antigen.epitope  ...  \
# 15     HomoSapiens     HLA-A*02   B2M      MHCI       LLWNGPMAV  ...
# 55     HomoSapiens     HLA-A*02   B2M      MHCI       LLWNGPMAV  ...
# 59     HomoSapiens     HLA-A*02   B2M      MHCI       LLWNGPMAV  ...
# 61     HomoSapiens     HLA-A*02   B2M      MHCI       LLWNGPMAV  ...
# 131    HomoSapiens  HLA-A*02:01   B2M      MHCI       GLCTLVAML  ...
# ...            ...          ...   ...       ...             ...  ...
# 75224  HomoSapiens     HLA-A*02   B2M      MHCI       NLVPMVATV  ...
# 75225  HomoSapiens     HLA-A*02   B2M      MHCI       NLVPMVATV  ...
# 75226  HomoSapiens     HLA-A*02   B2M      MHCI       NLVPMVATV  ...
# 75439  HomoSapiens  HLA-A*02:01   B2M      MHCI       GLCTLVAML  ...
# 75457  HomoSapiens  HLA-A*02:01   B2M      MHCI       GILGFVFTL  ...
#
#        cdr3fix.vId cdr3fix.oldVEnd cdr3fix.oldVFixType  cdr3fix.oldVId  \
# 15     TRAV12-2*01             NaN                 NaN             NaN
# 55       TRBV27*01             NaN                 NaN             NaN
# 59        TRBV9*01             NaN                 NaN             NaN
# 61     TRBV29-1*01             NaN                 NaN             NaN
# 131       TRBV9*01             NaN                 NaN             NaN
# ...            ...             ...                 ...             ...
# 75224  TRBV12-4*01             NaN                 NaN             NaN
# 75225    TRAV24*01             NaN                 NaN             NaN
# 75226    TRBV27*01             NaN                 NaN             NaN
# 75439   TRBV4-2*01             NaN                 NaN             NaN
# 75457    TRBV19*01             NaN                 NaN             NaN
#
#       cdr3fix.oldJFixType cdr3fix.oldJId cdr3fix.oldJStart  \
# 15            NoFixNeeded      TRAJ40*01              10.0
# 55            NoFixNeeded     TRBJ2-7*01              11.0
# 59            NoFixNeeded     TRBJ2-7*01              12.0
# 61            NoFixNeeded     TRBJ2-7*01              10.0
# 131                FixAdd            NaN              12.0
# ...                   ...            ...               ...
# 75224                 NaN            NaN               NaN
# 75225                 NaN            NaN               NaN
# 75226                 NaN            NaN               NaN
# 75439                 NaN            NaN               NaN
# 75457                 NaN            NaN               NaN
#
#                            merged cdr3.len antigen.epitope.len
# 15         CAVNSNTDKLIF-LLWNGPMAV       12                   9
# 55       CASSLNPSTDTQYF-LLWNGPMAV       14                   9
# 59      CASSATSGGADTQYF-LLWNGPMAV       15                   9
# 61        CSVPFAGADTQYF-LLWNGPMAV       13                   9
# 131     CASSSGQLTNTEAFF-GLCTLVAML       15                   9
# ...                           ...      ...                 ...
# 75224     CASSQALPYEQYF-NLVPMVATV       13                   9
# 75225       CAVCNFNKFYF-NLVPMVATV       11                   9
# 75226  CASSITLGTGGVEQYF-NLVPMVATV       16                   9
# 75439  CASSQDGAGGLGEQFF-GLCTLVAML       16                   9
# 75457     CASSIRSAYEQYF-GILGFVFTL       13                   9
#
# [53503 rows x 57 columns]

# %%
df_jan[~df_jan.fillna('NULL').apply(tuple,1).isin(df_aug.fillna('NULL').apply(tuple,1))]
# Out:
#        complex.id gene             cdr3         v.segm      j.segm  \
# 94              0  TRB     CASSYGGTEAFF     TRBV6-6*01  TRBJ1-1*01
# 95              0  TRB  CASSLPGQGRTPLHF     TRBV7-2*01  TRBJ1-6*01
# 163             0  TRA    CAAKTGGGNKLTF  TRAV29/DV5*01   TRAJ10*01
# 164             0  TRA    CAAKAGGGNKLTF  TRAV29/DV5*01   TRAJ10*01
# 166             0  TRA   CAGTDGGATNKLIF  TRAV36/DV7*01   TRAJ32*01
# ...           ...  ...              ...            ...         ...
# 76147       24634  TRB    CSARDRGREKLFF    TRBV20-1*01  TRBJ1-4*01
# 76148       24635  TRA      CAVNNNNDMRF    TRAV12-2*01   TRAJ43*01
# 76149       24635  TRB     CSGSQDPYEQYF    TRBV20-1*01  TRBJ2-7*01
# 76150       24636  TRA      CAVKFGQKLLF     TRAV1-2*01         NaN
# 76151       24636  TRB     CTAEAGNTEAFF     TRBV7-2*03  TRBJ1-1*01
#
#            species           mhc.a mhc.b mhc.class antigen.epitope  ...  \
# 94     HomoSapiens        HLA-B*08   B2M      MHCI        EIYKRWII  ...
# 95     HomoSapiens        HLA-B*08   B2M      MHCI        EIYKRWII  ...
# 163    HomoSapiens  HLA-B*44:03:08   B2M      MHCI        NEGVKAAW  ...
# 164    HomoSapiens  HLA-B*44:03:08   B2M      MHCI        NEGVKAAW  ...
# 166    HomoSapiens  HLA-B*44:03:08   B2M      MHCI        NEGVKAAW  ...
# ...            ...             ...   ...       ...             ...  ...
# 76147  HomoSapiens     HLA-A*68:01   B2M      MHCI    DATYQRTRALVR  ...
# 76148  HomoSapiens     HLA-A*68:01   B2M      MHCI    DATYQRTRALVR  ...
# 76149  HomoSapiens     HLA-A*68:01   B2M      MHCI    DATYQRTRALVR  ...
# 76150  HomoSapiens     HLA-A*68:01   B2M      MHCI    DATYQRTRALVR  ...
# 76151  HomoSapiens     HLA-A*68:01   B2M      MHCI    DATYQRTRALVR  ...
#
#          cdr3fix.vId cdr3fix.oldVEnd cdr3fix.oldVFixType  cdr3fix.oldVId  \
# 94        TRBV6-6*01             NaN                 NaN             NaN
# 95        TRBV7-2*01             NaN                 NaN             NaN
# 163    TRAV29/DV5*01             NaN                 NaN             NaN
# 164    TRAV29/DV5*01             NaN                 NaN             NaN
# 166    TRAV36/DV7*01             NaN                 NaN             NaN
# ...              ...             ...                 ...             ...
# 76147    TRBV20-1*01             NaN                 NaN             NaN
# 76148    TRAV12-2*01             NaN                 NaN             NaN
# 76149    TRBV20-1*01             NaN                 NaN             NaN
# 76150     TRAV1-2*01             NaN                 NaN             NaN
# 76151     TRBV7-2*03            -1.0   FailedNoAlignment     TRBV20-1*01
#
#       cdr3fix.oldJFixType cdr3fix.oldJStart cdr3fix.oldJId  \
# 94                    NaN               NaN            NaN
# 95                    NaN               NaN            NaN
# 163                   NaN               NaN            NaN
# 164                   NaN               NaN            NaN
# 166                   NaN               NaN            NaN
# ...                   ...               ...            ...
# 76147                 NaN               NaN            NaN
# 76148                 NaN               NaN            NaN
# 76149                 NaN               NaN            NaN
# 76150                 NaN               NaN            NaN
# 76151                 NaN               NaN            NaN
#
#                            merged cdr3.len antigen.epitope.len
# 94          CASSYGGTEAFF-EIYKRWII       12                   8
# 95       CASSLPGQGRTPLHF-EIYKRWII       15                   8
# 163        CAAKTGGGNKLTF-NEGVKAAW       13                   8
# 164        CAAKAGGGNKLTF-NEGVKAAW       13                   8
# 166       CAGTDGGATNKLIF-NEGVKAAW       14                   8
# ...                           ...      ...                 ...
# 76147  CSARDRGREKLFF-DATYQRTRALVR       13                  12
# 76148    CAVNNNNDMRF-DATYQRTRALVR       11                  12
# 76149   CSGSQDPYEQYF-DATYQRTRALVR       12                  12
# 76150    CAVKFGQKLLF-DATYQRTRALVR       11                  12
# 76151   CTAEAGNTEAFF-DATYQRTRALVR       12                  12
#
# [54193 rows x 57 columns]

# %%
df_diff = df_jan.fillna("NULL").merge(df_aug.fillna("NULL"),indicator = True, how='left').loc[lambda x : x['_merge']!='both']

# %%
df_diff["_merge"].value_counts()
# Out:
# left_only     49985
# both              0
# right_only        0
# Name: _merge, dtype: int64

# %%
df_aug.fillna("NULL").merge(df_jan.fillna("NULL"),indicator = True, how='left').loc[lambda x : x['_merge']!='both']["_merge"].value_counts()
# Out:
# left_only     49288
# both              0
# right_only        0
# Name: _merge, dtype: int64

# %%
df_aug.fillna("NULL").merge(df_jan.fillna("NULL"),indicator = True, how='outer').loc[lambda x : x['_merge']!='both']["_merge"].value_counts()
# Out:
# right_only    49985
# left_only     49288
# both              0
# Name: _merge, dtype: int64

# %%
df_diff = df_aug.fillna("NULL").merge(df_jan.fillna("NULL"),indicator = True, how='outer').loc[lambda x : x['_merge']!='both']

# %% [markdown]
# The fill.na is required since NaN equality comparison always returns false.

# %% [markdown]
# Row/series comparison

# %%
df_aug.loc[df_aug["cdr3"] == "CASSTAPGTEAFF"]
# Out:
#        complex.id gene           cdr3      v.segm      j.segm      species  \
# 66055           0  TRB  CASSTAPGTEAFF  TRBV5-4*01  TRBJ1-1*01  HomoSapiens
#
#           mhc.a mhc.b mhc.class antigen.epitope  ... cdr3fix.vId  \
# 66055  HLA-B*27   B2M      MHCI      KRWIILGLNK  ...  TRBV5-4*01
#
#       cdr3fix.oldVEnd cdr3fix.oldVFixType  cdr3fix.oldVId cdr3fix.oldJFixType  \
# 66055             NaN                 NaN             NaN                 NaN
#
#       cdr3fix.oldJId cdr3fix.oldJStart                    merged cdr3.len  \
# 66055            NaN               NaN  CASSTAPGTEAFF-KRWIILGLNK       13
#
#       antigen.epitope.len
# 66055                  10
#
# [1 rows x 57 columns]

# %%
df_jan.loc[df_jan["cdr3"] == "CASSTAPGTEAFF"]
# Out:
#      complex.id gene           cdr3      v.segm      j.segm      species  \
# 142           0  TRB  CASSTAPGTEAFF  TRBV5-4*01  TRBJ1-1*01  HomoSapiens
#
#         mhc.a mhc.b mhc.class antigen.epitope  ... cdr3fix.vId  \
# 142  HLA-B*27   B2M      MHCI      KRWIILGLNK  ...  TRBV5-4*01
#
#     cdr3fix.oldVEnd cdr3fix.oldVFixType  cdr3fix.oldVId cdr3fix.oldJFixType  \
# 142             NaN                 NaN             NaN                 NaN
#
#     cdr3fix.oldJStart cdr3fix.oldJId                    merged cdr3.len  \
# 142               NaN            NaN  CASSTAPGTEAFF-KRWIILGLNK       13
#
#     antigen.epitope.len
# 142                  10
#
# [1 rows x 57 columns]

# %% [markdown]
# Tuple comparison

# %%
df_jan.loc[df_jan["cdr3"] == "CASSTAPGTEAFF"].equals(df_jan.loc[df_jan["cdr3"] == "CASSTAPGTEAFF"])
# Out:
# True

# %%
a = df_aug.apply(tuple,1)[66055]

# %%
b = df_jan.apply(tuple,1)[142]

# %%
a == b
# Out:
# False

# %%
set(a) ^ set(b)
# Out:
# {nan, nan, nan, nan}

# %%
a > b
# Out:
# False

# %%
b > a
# Out:
# False

# %% [markdown]
# NaN messes up comparison, because NaN != NaN.

# %%
df_jan.loc[df_jan["cdr3"] == "CASSTAPGTEAFF", "cdr3fix.oldVEnd"] == df_jan.loc[df_jan["cdr3"] == "CASSTAPGTEAFF", "cdr3fix.oldVEnd"]
# Out:
# 142    False
# Name: cdr3fix.oldVEnd, dtype: bool

# %% [markdown]
# ## New values analysis

# %%
df_diff.shape[0]
# Out:
# 99273

# %%
df_diff.drop_duplicates(columns).shape[0]
# Out:
# 39976

# %%
print(f"There were {df_diff.shape[0] - df_diff.drop_duplicates(columns).shape[0]} duplicate CDR3-epitope pairs present in the new pairs.")
# Out:
# There were 59297 duplicate CDR3-epitope pairs present in the new pairs.

# %%
df_diff[df_diff["cdr3fix.good"]].drop_duplicates(columns).groupby("gene").size()
# Out:
# gene
# TRA    18505
# TRB    20320
# dtype: int64

# %%
df_diff[df_diff["cdr3fix.good"]].drop_duplicates(columns).groupby("antigen.epitope").size().sort_values(ascending=False)
# Out:
# antigen.epitope
# KLGGALQAK           24041
# AVFDRKSDAK           3168
# GILGFVFTL            1945
# RAKFKQLL             1305
# IVTDFSVIK            1044
#                     ...
# LLFGYPVAV               1
# ELAGIGALTV              1
# ELAAIGILTV              1
# GNSHRGAIEWEGIESG        1
# LLFGKPVYV               1
# Length: 153, dtype: int64

# %% [markdown]
# ## New unique pairs

# %%
df_diff_unique = df_jan.drop_duplicates(columns).fillna("NULL").merge(df_aug[columns].drop_duplicates(columns).fillna("NULL"),indicator = True, how='outer', on=columns).loc[lambda x : x['_merge']!='both']

# %%
df_diff_unique["_merge"].value_counts()
# Out:
# left_only     508
# both            0
# right_only      0
# Name: _merge, dtype: int64

# %%
df_diff_unique[df_diff_unique["cdr3fix.good"]].drop_duplicates(columns).groupby("gene").size()
# Out:
# gene
# TRA    112
# TRB    379
# dtype: int64

# %%
df_diff_unique[df_diff_unique["cdr3fix.good"]].drop_duplicates(columns).groupby("antigen.epitope").size().sort_values(ascending=False)
# Out:
# antigen.epitope
# DATYQRTRALVR       190
# RALEYKNL           163
# SSPPMFRV            84
# STRQALRPRADGPVG     15
# PSPSMGRDIKVQFQS      8
# MHVSFVMAYPEMLAA      8
# TAAQAAVVRFQEAAN      6
# LTDEQRAAALEKAAA      6
# MSQIMYNYPAMLGHA      4
# AAVVRFQEAANKQKQ      4
# PPQIAANRSQLISLV      3
# dtype: int64
